# %% [markdown]
# ## config

# %%
from os.path import join, exists, realpath
from os import makedirs

class Config():
  def __init__(self):
    # Paths
    self.input_path = join(realpath('.'), 'data', 'input')
      
    self.NI_data_path = join(self.input_path, 'People_NI_081124.csv') # 3,064 records EN 
    self.Wikidata_data_path = join(self.input_path, 'People_Wikidata_081124.csv') # 3.792 records EN
    self.RKD_data_path = join(self.input_path, 'RKDartists_architects_designers_noNationality_union.csv') # 4.331K records En


    self.results_path = join(realpath('.'), 'results')
    if not exists(self.results_path):
        makedirs(self.results_path)

    self.validation_sheets_path = join(self.results_path, 'validation')
    if not exists(self.validation_sheets_path):
        makedirs(self.validation_sheets_path)

    self.extract_n = 'all' # extract first n records if 'all' extract all records

    # Embeddings
    # TransH is a suitable choice for handling complex relational patterns in knowledge graphs,
    # including 1-to-many and many-to-1 relationships.
    # It builds on the strengths of TransE by introducing relation-specific hyperplanes,
    # making it more versatile for a wider range of relational data. Using TransH in PyKEEN can help you capture these relationships more effectively.
    self.embeddings_method = "TransH"

# %%
config = Config()

# %% [markdown]
# # ETL

# %%
import json
from os import makedirs
from os.path import join, exists, realpath

import pandas as pd
import pykeen.pipeline as pipeline
from pykeen.pipeline import PipelineResult
from pykeen.models import TransH  # should be loaded based on config file.
import numpy as np
from pykeen.triples import TriplesFactory

from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import torch

# import config


class ETL():
    def __init__(self, src_path, src_name):
        self.src_path = src_path
        self.src_name = src_name
        self.src_results_path = join(config.results_path, src_name)

        # Create mappings for entities and relations
        # self.entity_to_id = {}
        # self.relation_to_id = {}
        # self.next_entity_id = 0
        # self.next_relation_id = 0

        # self.get_triples_factory = None
        self.entity_embeddings, self.relations_embeddings, self.model = None, None, None
        self.embeddings_entity_np = None # numpy array format of entity embeddings

        self.subjects = []  # List to store unique subjects
        self.triples = []
        
    def try_parse_date(self, date_string):
        try:
            return parser.parse(date_string).date().strftime(
                '%Y-%m-%d')  # extract date part only and remove timespan part
        except (ValueError, TypeError) as e:
            # print(f"Error parsing date: {e}")
            return None
            
    def extract(self, keys, header=None):
        """
        Loads dataframe with only the given keys
        """
        df = pd.read_csv(self.src_path, names=keys, usecols=[i for i in range(len(keys))], dtype='str', header=header)
        df.dropna(how='all', inplace=True)
        df.fillna('', inplace=True)

        if config.extract_n != 'all':
            df = df.head(config.extract_n)

        print(f"Extracted {config.extract_n} records from {self.src_name}")

        return df
    
    def clean (self, df):
        pass
        
    def transform(self, raw_df, triples_path):
        """
        Transforms the dataframe into triples and save these triples in disk
        """
    
        df = self.clean(raw_df)
    
        preds = df.columns.tolist()
        for p in preds:
            print(p)
    
        
        # parses the dataframe into triples = [(s, p, o)]        
        for p in preds[1:]:
            for i, row in df.iterrows():
                s = row[preds[0]]
    
                o = row[p]
                # avoid filling empty triples
                if o == '':
                    continue
    
                if s not in self.subjects:
                    self.subjects += [s]
    
                multi_valued_o = o.split('<|>')
                for oi in multi_valued_o:
                    if [s, p, o] not in self.triples:
                         self.triples += [[s, p, oi]]
    
    
        # dump triples in a file on the disk
        df = pd.DataFrame(self.triples, columns=['s', 'p', 'o'], index=None)
        df.to_csv(triples_path)
        
        print(f'Saved {len(self.triples)} triples at {self.triples_path}')

        # store subjects to disk as well
        df = pd.DataFrame({'subjects': self.subjects})
        df.to_csv(join(self.src_results_path, 'subjects.csv'))


    def load(self, triples_path):
        """
        Loads pre-trained embeddings
        """
        df = pd.read_csv(triples_path, header=0, dtype=str)

        self.triples = df[['s', 'p', 'o']].values

        print(f'Loaded {len(self.triples)} triples from {triples_path}')

        return self.triples
        
    def run(self, keys, save_triples_to, header=None):
        df = self.extract(keys, header=header)
        self.transform(df, save_triples_to)
        triples = self.load(save_triples_to)
        return triples

# %%
def get_record(triples, s_uri):
    props = {}
    [props.update({prop:val}) for s,prop, val in triples if s == s_uri]
    return props

# %%
import torch

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
device
# Out:
# 'cuda'

# %% [markdown]
# # Embeddings Handler

# %%
def to_embeddings(triples, save_to):
    """
    Transforms the saved triples into embeddings space using pykeen
    """

    # Create a TriplesFactory from the converted triples
    triples_factory = TriplesFactory.from_labeled_triples(triples)

    # Check if GPU is available and set the device
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    
    print(f"Using device: {device}")

    result = pipeline.pipeline(
        training=triples_factory,
        testing=triples_factory,
        validation=triples_factory,
        model=config.embeddings_method,
        random_seed=42, # for reproducability
        model_kwargs=dict(embedding_dim=6),  # GPU Setting # dict(embedding_dim=50), # 
        optimizer='Adam',
        optimizer_kwargs=dict(lr=0.001, weight_decay=1e-5), # [Added Weight Decay] for better learning
        training_kwargs=dict(num_epochs=100, batch_size=256), #GPU Setting #dict(num_epochs=10, batch_size=64),
        negative_sampler='basic',  # Ensure negative sampling strategy
        negative_sampler_kwargs=dict(num_negs_per_pos=10),  # Number of negative samples per positive sample
        device=device
    )

    # saving the model
    makedirs(save_to, exist_ok=True)
    result.save_to_directory(directory=save_to, save_metadata=True, save_replicates=True, save_training=True)

    result.plot_losses()

    # Most models, like :class:`pykeen.models.TransE`, only have one representation for entities and one for relations.
    # This means that the entity_representations and relation_representations lists both have a length of 1. All of the entity embeddings can be accessed like:
    # saving the entity and relation embeddings
    entity_embeddings = result.model.entity_representations[0]
    relation_embeddings = result.model.relation_representations[0]

    entity_embeddings_path = join(save_to, 'entity_embeddings.npy')
    relation_embeddings_path = join(save_to, 'relation_embeddings.npy')

    np.save(entity_embeddings_path, entity_embeddings)
    np.save(relation_embeddings_path, relation_embeddings)

    print(f"Model saved to {save_to}")
    print(f"Entity embeddings saved to {entity_embeddings_path}")
    print(f"Relation embeddings saved to {relation_embeddings_path}")

    return triples_factory

# %%
def load_embeddings(read_from_dir):
    """
    Loads embeddings format of the src
    """
    import torch

    # Load your pre-trained model
    model = torch.load(join(read_from_dir, 'trained_model.pkl'))

    # Most models, like :class:`pykeen.models.TransE`, only have one representation for entities and one for relations.
    # This means that the entity_representations and relation_representations lists both have a length of 1. All of the entity embeddings can be accessed like:
    entity_representations = model.entity_representations[0]
    relation_representations = model.relation_representations[0]

    # # Alternatively, if you have pre-trained numpy arrays
    # entity_embeddings = np.load(join(read_from_dir, 'entity_embeddings.npy'))
    # relation_embeddings = np.load(join(read_from_dir, 'relation_embeddings.npy'))

     # Convert the embeddings to a NumPy array
    embeddings_entity_tensor = entity_representations._embeddings.weight  # Access the underlying PyTorch tensor
    embeddings_entity_np = embeddings_entity_tensor.detach().cpu().numpy()  # Convert to a NumPy array

    embeddings_relation_tensor = relation_representations._embeddings.weight  # Access the underlying PyTorch tensor
    embeddings_relation_np = embeddings_relation_tensor.detach().cpu().numpy()  # Convert to a NumPy array


    # Print the shapes to verify
    print("NumPy Entity Embeddings Array Shape:", embeddings_entity_np.shape)
    print("NumPy Relation Embeddings Array Shape:", embeddings_relation_np.shape)
    # print("List Length:", len(embeddings_list))

    return embeddings_entity_np, embeddings_relation_np, model

# %% [markdown]
# # Similarity Compuatation & Plotting

# %%
def find_top_similar(src_vectors, target_vectors, top_n=3):
    print("Shape for src vectors and dest vectors are")
    print(f"src_vectors shape {src_vectors.shape} vs target_vectors shape {target_vectors.shape}")
    
    
    similarities = cosine_similarity(src_vectors, target_vectors)[0]
    print(f"Similarity Matrix:")
    print(similarities)

    # pick top n similar vectors from target to src
    top_indices = np.argsort(similarities)[::-1][:top_n]
    return top_indices, similarities[top_indices]

# %%
def plot_vectors(src_vectors_2d, src_labels, dest_vectors_2d, dest_labels, annotate=False):
    # Plot the vectors
    plt.figure(figsize=(25, 25))
    
    plt.scatter(src_vectors_2d[:, 0], src_vectors_2d[:, 1], c='blue', marker='o', label='Src Vectors')
    plt.scatter(dest_vectors_2d[:, 0], dest_vectors_2d[:, 1], c='red', marker='x', label='Dest Vectors')
    
    # # Annotate the points
    if annotate:
        for i, (x, y) in enumerate(src_vectors_2d):
          plt.text(x, y, f"{src_labels[i]}", fontsize=12)
        
        # Annotate the points
        for i, (x, y) in enumerate(dest_vectors_2d):
          plt.text(x, y, f"{dest_labels[i]}", fontsize=12)
        
    plt.title("2D Visualization of High-Dimensional Vectors using t-SNE")
    plt.xlabel("Component 1")
    plt.ylabel("Component 2")
    plt.grid(True)
    plt.show()

# %%
 def handle_similarity(src_vectors, target_vectors, src_vector_labels, target_vectors_labels, annotate=False):

      # top_indices, top_similarities = find_top_similar(src_vectors, target_vectors)
      # print(f"Top {len(top_indices)} similar vectors to {target_vectors}:")
      # for index, similarity in zip(top_indices, top_similarities):
      #     print(f"Index: {index}, Vector: {src_vectors[index]}, Similarity: {similarity}")

      # Reduce dimensions to 2D using t-SNE
      tsne = TSNE(n_components=2, perplexity=2, random_state=0)  # Adjusted perplexity to 2
      src_vectors_2d = tsne.fit_transform(src_vectors)
      target_vectors_2d = tsne.fit_transform(target_vectors)

      # Plot the vectors
      plot_vectors(src_vectors_2d, src_vector_labels, target_vectors_2d, target_vectors_labels, annotate)

# %%
def Compute_cosine_similarity(embeddings_entity_np):
    similarity_matrix = cosine_similarity(embeddings_entity_np)
    print("Cosine Similarity Matrix:")
    print(similarity_matrix)

# %%
def compute_overlap(triples_factory, src_ids, src_vectors_np, src_labels, target_ids, target_vectors_np, target_vectors_labels,  threshold = 0.98):

    """
    This function computes the overlap between src subjects and the target subjects. Both subjects are expected to be in np format 
    """
    # We retrieve the subset of the emebeddings_entity that holds only subjects
    print(f"Subjects 'src_vectors_np' shape: {src_vectors_np.shape}")
    print(f"Subjects 'vector_vectors_np' shape: {target_vectors_np.shape}")
        

    # computes the similarity matrix between src and target embeddings_entity
    entity_similarity_matrix = cosine_similarity(src_vectors_np, target_vectors_np)
    #relation_similarity_matrix = cosine_similarity(subject_rel_embeddings_np, target_rel_vectors_np)

    # # Find the overlap with high similarity scores (If we would like to retrieve all possible matches)
    high_similarity_entities = np.argwhere(entity_similarity_matrix > threshold)
    # # high_similarity_relations = np.argwhere(relation_similarity_matrix > threshold)
    
    highest_sim = - 1
    # print("High Similarity Entities (src_id, dest_id, similarity_score):")
    similar_pairs_dict = {}
    for src_id, sim_list in enumerate(entity_similarity_matrix):
        #limit display to subjects only in both src and targets
        dest_id = np.argmax(sim_list)
        best_similarity_score = sim_list[dest_id]
        if best_similarity_score > highest_sim:
            highest_sim = best_similarity_score
        if best_similarity_score > threshold:
          similarity_score = entity_similarity_matrix[src_id, dest_id]
          s = triples_factory.entity_id_to_label[src_ids[src_id]]
          d = triples_factory.entity_id_to_label[target_ids[dest_id]]
          print(f"src: {s}, dest: {d}, score: {similarity_score:.4f}")
          similar_pairs_dict.update({ (s,d) :similarity_score})
    print(f"Highest Similarity Score: {highest_sim}")
    return similar_pairs_dict

# %% [markdown]
# # Data Exploration

# %%
from collections import Counter, defaultdict

def inspect(etl_obj):
    # df = etl_obj.extract(keys=etl_obj.keys)
    # etl_obj.transform(df, etl_obj.triples_path)
    triples = etl_obj.load(etl_obj.triples_path)

    print('Check Data Quality')
    print('a. Check for Missing Values Ensure that your triples don\'t contain missing values, as these can affect '
          'model performance.')
    missing_triples = [triple for triple in triples if None in triple]
    print(f"Missing triples: {missing_triples}\n")

    print('b. Validate Entity and Relation Distribution Analyze the distribution of entities and relations in your '
          'data to understand the structure and balance.')
    entities = [triple[0] for triple in triples] + [triple[2] for triple in triples]
    relations = [triple[1] for triple in triples]

    entity_counts = Counter(entities)
    relation_counts = Counter(relations)

    print(f"Top 10 entities: {entity_counts.most_common(10)}")
    print(f"Top 10 relations: {relation_counts.most_common(10)}\n")

    # # Extract entities and relations
    # entities = [triple[0] for triple in triples] + [triple[2] for triple in triples]
    # relations = [triple[1] for triple in triples]

    # # Count frequencies
    # entity_counts = Counter(entities)
    # relation_counts = Counter(relations)

    # # Plot entity distribution
    # entity_labels, entity_freqs = zip(*entity_counts.items())
    # plt.figure(figsize=(10, 5))
    # plt.bar(entity_labels, entity_freqs)
    # plt.xticks(rotation=90)
    # plt.title('Entity Frequency Distribution')
    # plt.xlabel('Entities')
    # plt.ylabel('Frequency')
    # plt.show()

    print('2. Analyze Relationship Types Understanding the types of relationships in your data (e.g., 1-to-1, '
          '1-to-many, many-to-1, many-to-many) can help you choose the right model:')
    entity_to_relations = defaultdict(list)
    for h, r, t in triples:
        entity_to_relations[h].append(r)
        entity_to_relations[t].append(r)

    one_to_one = sum(1 for rels in entity_to_relations.values() if len(set(rels)) == 1)
    one_to_many = sum(1 for rels in entity_to_relations.values() if len(set(rels)) > 1)
    many_to_one = len(entity_to_relations) - one_to_many

    print(f"One-to-One: {one_to_one}, One-to-Many: {one_to_many}, Many-to-One: {many_to_one}\n")

    # print('3. Visualize the Knowledge Graph Visualizing your knowledge graph can provide insights into its structure and potential issues.')
    # import networkx as nx
    # import matplotlib.pyplot as plt

    # G = nx.DiGraph()
    # G.add_edges_from([(h, t) for h, r, t in triples])

    # plt.figure(figsize=(12, 12))
    # nx.draw(G, with_labels=True, node_size=500, node_color="skyblue", pos=nx.spring_layout(G))
    # plt.show()

    # # Plot relation distribution
    # relation_labels, relation_freqs = zip(*relation_counts.items())
    # plt.figure(figsize=(10, 5))
    # plt.bar(relation_labels, relation_freqs)
    # plt.xticks(rotation=90)
    # plt.title('Relation Frequency Distribution')
    # plt.xlabel('Relations')
    # plt.ylabel('Frequency')
    # plt.show()

    # # Print top 10 entities and relations
    # print(f"Top 10 entities: {entity_counts.most_common(10)}")
    # print(f"Top 10 relations: {relation_counts.most_common(10)}")

# %% [markdown]
# # Datasets
# We have three options so far: HNI, Wikidata, and RKD

# %% [markdown]
# ## NI ETL

# %%
import json
from os import makedirs
from os.path import join, exists, realpath
from dateutil import parser

class NI_ETL(ETL):
    def __init__(self):
        self.keys = [
            "s",
            "name",
            "birthDate",
            "deathDate",
            "birthPlace",
            "deathPlace",
            "occupation",
            #"memberOfs",
            #"memberOfDescriptions"
        ]

        super().__init__(src_name="NI", src_path=config.NI_data_path)
        print(config.NI_data_path)
        self.triples_path = join(realpath('.'), 'results', self.src_name)
        makedirs(self.triples_path, exist_ok=True)
        self.triples_path = join(self.triples_path,  'triples.csv')


    def __clean_names(self, row):
        to_remove_chars = [',', '+', '-', '&', '.', '(', ')', '[', ']', '!', '"', "'", "\\", "/"]

        # starting with names
        multi_s = row['name'].split('<|>')

        current_processed_names, current_initials = [], []
        for s in multi_s:
            # apply cleaning step for name
            tt = str.maketrans({char: ' ' for char in to_remove_chars})
            processed = s.translate(tt)
            current_processed_names += [processed]

            # Get initials of this name
            words = list(set(processed.split(' ')))
            long_words = [w for w in words if len(w) > 1 if w.lower() not in ['van', 'der', 'den']]
            initials = list(set([w[0] for w in long_words]))
            current_initials += [''.join(initials)]

        # store cleaned versions of both names and initials
        cleaned_names = ['<|>'.join([n for n in current_processed_names])]
        cleaned_initials = ['<|>'.join([i for i in set(current_initials)])]
        return cleaned_names, cleaned_initials

    def clean(self, df):
        print(len(df))
        print("Cleaning NI data ...")

        # placeholders for clean values
        cleaned_names, cleaned_initials, clean_birthdates, clean_deathdates, clean_birthplaces, clean_deathplaces, clean_occupations \
        = [], [], [], [], [], [], []

        # we provide a data cleaning for Name, dates related fields
        for i, row in df.iterrows():

            # cleaned_names, cleaned_initials
            var1, var2 = self.__clean_names(row)
            cleaned_names += var1
            # cleaned_initials += var2

            # cleaning dates-related fields
            current_processed_bds, current_processed_dds = [], []
            multi_bd = str(row['birthDate']).split('<|>')
            multi_dd = str(row['deathDate']).split('<|>')

            for bd in multi_bd:
                parsed_date = self.try_parse_date(bd)
                if parsed_date:
                    current_processed_bds += [parsed_date]

            for dd in multi_dd:
                parsed_date = self.try_parse_date(dd)
                if parsed_date:
                    current_processed_dds += [parsed_date]

            clean_birthdates += ['<|>'.join([bd for bd in current_processed_bds])]
            clean_deathdates += ['<|>'.join([dd for dd in current_processed_dds])]

            multi_birthPlace = list(set(str(row['birthPlace']).split('<|>')))
            multi_deathPlace = list(set(str(row['deathPlace']).split('<|>')))
            multi_occupation = list(set(str(row['occupation']).split('<|>')))

            clean_birthplaces += ['<|>'.join([bp for bp in multi_birthPlace])]
            clean_deathplaces += ['<|>'.join([dp for dp in multi_deathPlace])]
            clean_occupations += ['<|>'.join([o for o in multi_occupation])]

        # Constrcut a new Dataframe with the new cleaned data  
        clean_df = pd.DataFrame({
            "s": df["s"],
            "name": cleaned_names,
            "birthdate": clean_birthdates,
            "deathdate": clean_deathdates,
            "birthPlace": clean_birthplaces,
            "deathPlace": clean_deathplaces,
            "occupation": clean_occupations,
            # "initials": cleaned_initials,
            #"memberOfs": df["memberOfs"]
        }, dtype=str)

        # store cleaned version of the dataset on disk
        print('store in disk')
        clean_df.to_csv(join(realpath('.'), 'results', self.src_name, '{}_clean_data.csv'.format(self.src_name)), encoding='utf8', index=None)
        return clean_df

# %%
ni_etl_obj = NI_ETL()
# Out:
# /home/muhammad/Downloads/LOD-Linker/data/input/People_NI_081124.csv

# %%
ni_triples = ni_etl_obj.run(keys=ni_etl_obj.keys,
                save_triples_to=ni_etl_obj.triples_path)
# Out:
# Extracted all records from NI
# 3064
# Cleaning NI data ...
# store in disk
# s
# name
# birthdate
# deathdate
# birthPlace
# deathPlace
# occupation
# Saved 21983 triples at /home/muhammad/Downloads/LOD-Linker/results/NI/triples.csv
# Loaded 21983 triples from /home/muhammad/Downloads/LOD-Linker/results/NI/triples.csv

# %%
inspect(ni_etl_obj)
# Out:
# Loaded 21983 triples from /home/muhammad/Downloads/LOD-Linker/results/NI/triples.csv
# Check Data Quality
# a. Check for Missing Values Ensure that your triples don't contain missing values, as these can affect model performance.
# Missing triples: []
#
# b. Validate Entity and Relation Distribution Analyze the distribution of entities and relations in your data to understand the structure and balance.
# Top 10 entities: [('architect', 2495), ('Amsterdam', 929), ('Rotterdam', 411), ('photographer', 368), ('The Hague', 319), ('Utrecht (city)', 175), ('Haarlem', 146), ('Arnhem', 141), ('Groningen (city)', 112), ('Leiden', 99)]
# Top 10 relations: [('name', 6128), ('occupation', 3599), ('birthdate', 3064), ('deathdate', 3064), ('birthPlace', 3064), ('deathPlace', 3064)]
#
# 2. Analyze Relationship Types Understanding the types of relationships in your data (e.g., 1-to-1, 1-to-many, many-to-1, many-to-many) can help you choose the right model:
# One-to-One: 8399, One-to-Many: 3384, Many-to-One: 8399

# %%
ni_etl_obj.subjects[0:10]
# Out:
# ['https://collectiedata.hetnieuweinstituut.nl/id/people/10147',
#  'https://collectiedata.hetnieuweinstituut.nl/id/people/10151',
#  'https://collectiedata.hetnieuweinstituut.nl/id/people/10171',
#  'https://collectiedata.hetnieuweinstituut.nl/id/people/10192',
#  'https://collectiedata.hetnieuweinstituut.nl/id/people/10226',
#  'https://collectiedata.hetnieuweinstituut.nl/id/people/10282',
#  'https://collectiedata.hetnieuweinstituut.nl/id/people/10316',
#  'https://collectiedata.hetnieuweinstituut.nl/id/people/10414',
#  'https://collectiedata.hetnieuweinstituut.nl/id/people/10562',
#  'https://collectiedata.hetnieuweinstituut.nl/id/people/10663']

# %%
ni_etl_obj.triples[0:10]
# Out:
# array([['https://collectiedata.hetnieuweinstituut.nl/id/people/10147',
#         'name', 'Tak  Christinus Bonifacius van der  sr  '],
#        ['https://collectiedata.hetnieuweinstituut.nl/id/people/10147',
#         'name', 'Branch  Christinus Bonifacius van der  sr  '],
#        ['https://collectiedata.hetnieuweinstituut.nl/id/people/10151',
#         'name', 'Branch  Gerardus Pieter van der'],
#        ['https://collectiedata.hetnieuweinstituut.nl/id/people/10151',
#         'name', 'Tak  Gerardus Pieter van der'],
#        ['https://collectiedata.hetnieuweinstituut.nl/id/people/10171',
#         'name', 'Middelhoek  Abraham'],
#        ['https://collectiedata.hetnieuweinstituut.nl/id/people/10171',
#         'name', 'Middelhoek  Abraham'],
#        ['https://collectiedata.hetnieuweinstituut.nl/id/people/10192',
#         'name', 'Verhagen  Pieter'],
#        ['https://collectiedata.hetnieuweinstituut.nl/id/people/10192',
#         'name', 'Verhagen  Pieter'],
#        ['https://collectiedata.hetnieuweinstituut.nl/id/people/10226',
#         'name', 'Besnyö  Eva'],
#        ['https://collectiedata.hetnieuweinstituut.nl/id/people/10226',
#         'name', 'Besnyö  Eva']], dtype=object)

# %% [markdown]
# ## Wikidata ETL

# %%
import json
from os import makedirs
from os.path import join, exists, realpath


class Wikidata_ETL(ETL):
    def __init__(self):
        self.keys = [
            "s",
            "name",
            "birthDate",
            "birthPlace",
            "deathDate",
            "deathPlace",
            "occupation"
            # "archiveAt",
            # "memberOf"
        ]

        super().__init__(src_name="Wikidata", src_path=config.Wikidata_data_path)

        self.triples_path = join(realpath('.'), 'results', self.src_name)
        makedirs(self.triples_path, exist_ok=True)
        self.triples_path = join(self.triples_path,  'triples.csv')

    def __clean_names(self, row):
        to_remove_chars = [',', '+', '-', '&', '.', '(', ')', '[', ']', '!', '"', "'", "\\", "/"]

        # starting with names
        multi_s = row['name'].split('<|>')

        current_processed_names, current_initials = [], []
        for s in multi_s:
            # apply cleaning step for name
            tt = str.maketrans({char: ' ' for char in to_remove_chars})
            processed = s.translate(tt)
            current_processed_names += [processed]

            # Get initials of this name
            words = list(set(processed.split(' ')))
            long_words = [w for w in words if len(w) > 1 if w.lower() not in ['van', 'der', 'den']]
            initials = list(set([w[0] for w in long_words]))
            current_initials += [''.join(initials)]

        # store cleaned versions of both names and initials
        cleaned_names = ['<|>'.join([n for n in current_processed_names])]
        cleaned_initials = ['<|>'.join([i for i in set(current_initials)])]
        return cleaned_names, cleaned_initials

    def clean(self, df):
        print(len(df))
        print("Cleaning Wikidata data ...")

        # placeholders for clean values
        cleaned_names, cleaned_initials, clean_birthdates, clean_deathdates, clean_birthplaces, clean_deathplaces, clean_occupations = [], [], [], [], [], [], []

        # we provide a data cleaning for Name, dates related fields
        for i, row in df.iterrows():

            # cleaned_names, cleaned_initials
            var1, var2 = self.__clean_names(row)
            cleaned_names += var1
            # cleaned_initials += var2

            # cleaning dates-related fields
            current_processed_bds, current_processed_dds = [], []
            multi_bd = str(row['birthDate']).split('<|>')
            multi_dd = str(row['deathDate']).split('<|>')

            for bd in multi_bd:
                parsed_date = self.try_parse_date(bd)
                if parsed_date:
                    current_processed_bds += [parsed_date]

            for dd in multi_dd:
                parsed_date = self.try_parse_date(dd)
                if parsed_date:
                    current_processed_dds += [parsed_date]

            clean_birthdates += ['<|>'.join([bd for bd in current_processed_bds])]
            clean_deathdates += ['<|>'.join([dd for dd in current_processed_dds])]

            multi_birthPlace = list(set(str(row['birthPlace']).split('<|>')))
            multi_deathPlace = list(set(str(row['deathPlace']).split('<|>')))
            multi_occupation = list(set(str(row['occupation']).split('<|>')))
            
            clean_birthplaces += ['<|>'.join([bp for bp in multi_birthPlace])]
            clean_deathplaces += ['<|>'.join([dp for dp in multi_deathPlace])]
            clean_occupations += ['<|>'.join([o for o in multi_occupation])]

        # Constrcut a new Dataframe with the new cleaned data
 
        clean_df = pd.DataFrame({
            "s": df["s"],
            "name": cleaned_names,
            "birthdate": clean_birthdates,
            "deathdate": clean_deathdates,
            "birthPlace": clean_birthplaces,
            "deathPlace": clean_deathplaces,
            "occupation": clean_occupations,
            # "initials": cleaned_initials,
            #"memberOf": df["memberOf"],
            #"archiveAt": df["archiveAt"],
        }, dtype=str)

        # store cleaned version of the dataset on disk
        print('store in disk')
        clean_df.to_csv(join(realpath('.'), 'results', self.src_name, '{}_clean_data.csv'.format(self.src_name)), encoding='utf8', index=None)
        return clean_df

# %%
wikidata_etl_obj = Wikidata_ETL()

# %%
wikidata_etl_obj.run(keys=wikidata_etl_obj.keys,
                     save_triples_to=wikidata_etl_obj.triples_path)
                     #header=0) # Wikidata file has a valid header we should exclude it from reading
# Out:
# Extracted all records from Wikidata
# 3793
# Cleaning Wikidata data ...
# store in disk
# s
# name
# birthdate
# deathdate
# birthPlace
# deathPlace
# occupation
# Saved 22460 triples at /home/muhammad/Downloads/LOD-Linker/results/Wikidata/triples.csv
# Loaded 22460 triples from /home/muhammad/Downloads/LOD-Linker/results/Wikidata/triples.csv
# array([['person', 'name', 'personLabels'],
#        ['http://www.wikidata.org/entity/Q160422', 'name',
#         'Theo van Doesburg'],
#        ['http://www.wikidata.org/entity/Q447182', 'name', 'Mien Ruys'],
#        ...,
#        ['http://www.wikidata.org/entity/Q130232419', 'occupation',
#         'architect'],
#        ['http://www.wikidata.org/entity/Q130248747', 'occupation',
#         'architect'],
#        ['http://www.wikidata.org/entity/Q130647298', 'occupation',
#         'architect']], dtype=object)

# %%
inspect(wikidata_etl_obj)
# Out:
# Loaded 22460 triples from /home/muhammad/Downloads/LOD-Linker/results/Wikidata/triples.csv
# Check Data Quality
# a. Check for Missing Values Ensure that your triples don't contain missing values, as these can affect model performance.
# Missing triples: []
#
# b. Validate Entity and Relation Distribution Analyze the distribution of entities and relations in your data to understand the structure and balance.
# Top 10 entities: [('photographer', 2502), ('architect', 972), ('Amsterdam', 615), ('designer', 428), ('The Hague', 377), ('Rotterdam', 240), ('Utrecht', 136), ('Haarlem', 115), ('Groningen', 75), ('Arnhem', 55)]
# Top 10 relations: [('occupation', 3903), ('deathdate', 3892), ('birthdate', 3877), ('name', 3793), ('birthPlace', 3793), ('deathPlace', 3202)]
#
# 2. Analyze Relationship Types Understanding the types of relationships in your data (e.g., 1-to-1, 1-to-many, many-to-1, many-to-many) can help you choose the right model:
# One-to-One: 8053, One-to-Many: 7360, Many-to-One: 8053

# %%
wikidata_etl_obj.subjects[0:10]
# Out:
# ['person',
#  'http://www.wikidata.org/entity/Q160422',
#  'http://www.wikidata.org/entity/Q447182',
#  'http://www.wikidata.org/entity/Q79000',
#  'http://www.wikidata.org/entity/Q117259',
#  'http://www.wikidata.org/entity/Q118476',
#  'http://www.wikidata.org/entity/Q126499',
#  'http://www.wikidata.org/entity/Q132142',
#  'http://www.wikidata.org/entity/Q132305',
#  'http://www.wikidata.org/entity/Q153890']

# %%
wikidata_etl_obj.triples[0:10]
# Out:
# array([['person', 'name', 'personLabels'],
#        ['http://www.wikidata.org/entity/Q160422', 'name',
#         'Theo van Doesburg'],
#        ['http://www.wikidata.org/entity/Q447182', 'name', 'Mien Ruys'],
#        ['http://www.wikidata.org/entity/Q79000', 'name', 'Pieter Zeeman'],
#        ['http://www.wikidata.org/entity/Q117259', 'name', 'Arent Passer'],
#        ['http://www.wikidata.org/entity/Q118476', 'name',
#         'Evariste Mertens'],
#        ['http://www.wikidata.org/entity/Q126499', 'name',
#         'Wilhelm Emil Meerwein'],
#        ['http://www.wikidata.org/entity/Q132142', 'name',
#         'Henri Alexis Brialmont'],
#        ['http://www.wikidata.org/entity/Q132305', 'name',
#         'Willem de Kooning'],
#        ['http://www.wikidata.org/entity/Q153890', 'name',
#         'Niko Tinbergen']], dtype=object)

# %% [markdown]
# ## RKD

# %%
import json
from os import makedirs
from os.path import join, exists, realpath


class RKD_ETL(ETL):
    def __init__(self):
        self.keys = [
          "s",
          "name",
          "birthDate",
          "deathDate",
          "birthPlace",
          "deathPlace",          
          "occupation", 
         ]

        super().__init__(src_name="RKD", src_path=config.RKD_data_path)

        self.triples_path = join(realpath('.'), 'results', self.src_name)
        makedirs(self.triples_path, exist_ok=True)
        self.triples_path = join(self.triples_path,  'triples.csv')
        

    def __clean_names(self, row):
        to_remove_chars = [',', '+', '-', '&', '.', '(', ')', '[', ']', '!', '"', "'", "\\", "/"]

        # starting with names
        multi_s = row['name'].split('<|>')

        current_processed_names, current_initials = [], []
        for s in multi_s:
            # apply cleaning step for name
            tt = str.maketrans({char: ' ' for char in to_remove_chars})
            processed = s.translate(tt)
            current_processed_names += [processed]

            # Get initials of this name
            words = list(set(processed.split(' ')))
            long_words = [w for w in words if len(w) > 1 if w.lower() not in ['van', 'der', 'den']]
            initials = list(set([w[0] for w in long_words]))
            current_initials += [''.join(initials)]

        # store cleaned versions of both names and initials
        cleaned_names = ['<|>'.join([n for n in current_processed_names])]
        cleaned_initials = ['<|>'.join([i for i in set(current_initials)])]
        return cleaned_names, cleaned_initials

    def clean(self, df):
        print(len(df))
        print("Cleaning RKD data ...")

        # placeholders for clean values
        cleaned_names, cleaned_initials, clean_birthdates, clean_deathdates, \
        cleaned_birthplaces, cleaned_deathplaces, cleaned_occupations = [], [], [], [], [], [], []

        # we provide a data cleaning for Name, dates related fields
        for i, row in df.iterrows():

            # cleaned_names, cleaned_initials
            var1, var2 = self.__clean_names(row)
            cleaned_names += var1
            # cleaned_initials += var2

            # cleaning dates-related fields
            current_processed_bds, current_processed_dds = [], []
            multi_bd = str(row['birthDate']).split('<|>')
            multi_dd = str(row['deathDate']).split('<|>')

            for bd in multi_bd:
                parsed_date = self.try_parse_date(bd)
                if parsed_date:
                    current_processed_bds += [parsed_date]

            for dd in multi_dd:
                parsed_date = self.try_parse_date(dd)
                if parsed_date:
                    current_processed_dds += [parsed_date]

            clean_birthdates += ['<|>'.join([bd for bd in current_processed_bds])]
            clean_deathdates += ['<|>'.join([dd for dd in current_processed_dds])]

            # birth and death places are often contains (staad), (city)
            b_place = str(row['birthPlace'])
            cleaned_birthplaces += [b_place.split('(')[0].strip()]
            d_place = str(row['deathPlace'])
            cleaned_deathplaces += [d_place.split('(')[0].strip()]

            
            multi_occupation = list(set(str(row['occupation']).split('<|>')))
            cleaned_occupations += ['<|>'.join([o for o in multi_occupation])]
        # Constrcut a new Dataframe with the new cleaned data       

        clean_df = pd.DataFrame({
            "s": df["s"],
            "name": cleaned_names,
            "birthdate": clean_birthdates,
            "deathdate": clean_deathdates,
            # "initials": cleaned_initials,
            "birthplace": cleaned_birthplaces, 
            "deathplace": cleaned_deathplaces,    
            "occupation": cleaned_occupations,
            #"memberOf": df["memberOf"],
        }, dtype=str)

        # store cleaned version of the dataset on disk
        print('store in disk')
        clean_df.to_csv(join(realpath('.'), 'results', self.src_name, '{}_clean_data.csv'.format(self.src_name)), encoding='utf8',
                        index=None)
        return clean_df

# %%
rkd_etl_obj = RKD_ETL()

# %%
rkd_etl_obj.run(keys=rkd_etl_obj.keys,
                save_triples_to=rkd_etl_obj.triples_path)
# Out:
# Extracted all records from RKD
# 4331
# Cleaning RKD data ...
# store in disk
# s
# name
# birthdate
# deathdate
# birthplace
# deathplace
# occupation
# Saved 44850 triples at /home/muhammad/Downloads/LOD-Linker/results/RKD/triples.csv
# Loaded 44850 triples from /home/muhammad/Downloads/LOD-Linker/results/RKD/triples.csv
# array([['https://data.rkd.nl/artists/101500', 'name', 'De Neste  Alfred'],
#        ['https://data.rkd.nl/artists/101500', 'name',
#         'Neste  Alfred van'],
#        ['https://data.rkd.nl/artists/101500', 'name',
#         'Van Neste  Alfred'],
#        ...,
#        ['https://data.rkd.nl/artists/74117', 'occupation',
#         'jeweler (craftsperson)'],
#        ['https://data.rkd.nl/artists/309239', 'occupation',
#         'scenographer'],
#        ['https://data.rkd.nl/artists/309239', 'occupation', 'designer']],
#       dtype=object)

# %%
inspect(rkd_etl_obj)
# Out:
# Loaded 44850 triples from /home/muhammad/Downloads/LOD-Linker/results/RKD/triples.csv
# Check Data Quality
# a. Check for Missing Values Ensure that your triples don't contain missing values, as these can affect model performance.
# Missing triples: []
#
# b. Validate Entity and Relation Distribution Analyze the distribution of entities and relations in your data to understand the structure and balance.
# Top 10 entities: [('architect', 2275), ('painter', 2250), ('designer', 1928), ('draftsperson', 1810), ('sculptor', 938), ('watercolorist', 656), ('illustrator', 619), ('graphic artist', 617), ('Paris', 530), ('Amsterdam', 492)]
# Top 10 relations: [('occupation', 18425), ('name', 9692), ('deathplace', 4348), ('birthplace', 4343), ('deathdate', 4106), ('birthdate', 3936)]
#
# 2. Analyze Relationship Types Understanding the types of relationships in your data (e.g., 1-to-1, 1-to-many, many-to-1, many-to-many) can help you choose the right model:
# One-to-One: 18521, One-to-Many: 5017, Many-to-One: 18521

# %% [markdown]
# ## Traning

# %%
all_triples = np.concatenate((ni_etl_obj.triples, wikidata_etl_obj.triples, rkd_etl_obj.triples), axis=0)

# %%
all_triples = all_triples.astype(str)

# %%
all_triples.shape
# Out:
# (89293, 3)

# %%
triples_factory = to_embeddings(all_triples, config.results_path)
# Out:
# Using device: cuda
# Training epochs on cuda:0:   0%|          | 0/100 [00:00<?, ?epoch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/339 [00:00<?, ?batch/s]
# Evaluating on cuda:0:   0%|          | 0.00/86.6k [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 9.34s seconds
# INFO:pykeen.triples.triples_factory:Stored TriplesFactory(num_entities=46128, num_relations=8, create_inverse_triples=False, num_triples=86606) to file:///home/muhammad/Downloads/LOD-Linker/results/training_triples
# INFO:pykeen.pipeline.api:Saved to directory: /home/muhammad/Downloads/LOD-Linker/results
# Model saved to /home/muhammad/Downloads/LOD-Linker/results
# Entity embeddings saved to /home/muhammad/Downloads/LOD-Linker/results/entity_embeddings.npy
# Relation embeddings saved to /home/muhammad/Downloads/LOD-Linker/results/relation_embeddings.npy

# %%
embeddings_entity_np, embeddings_relation_np, model = load_embeddings(config.results_path)
# Out:
# NumPy Entity Embeddings Array Shape: (46128, 6)
# NumPy Relation Embeddings Array Shape: (8, 6)
# /tmp/ipykernel_273599/1086840169.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(join(read_from_dir, 'trained_model.pkl'))

# %% [markdown]
# ## Similarity

# %%
src_ids = triples_factory.entities_to_ids([s for s in ni_etl_obj.subjects])

# %%
src_vectors = embeddings_entity_np[triples_factory.entities_to_ids(src_ids)]

# %%
src_labels = [s for s in ni_etl_obj.subjects]

# %% [markdown]
# ### Wikidata Similarity

# %%
target_ids = triples_factory.entities_to_ids([s for s in wikidata_etl_obj.subjects])

# %%
target_vectors = embeddings_entity_np[target_ids]

# %%
target_vectors_labels =[s for s in wikidata_etl_obj.subjects]

# %%
handle_similarity(src_vectors, target_vectors, src_labels, target_vectors_labels, annotate=False)

# %%
similar_wiki_pairs_dict = compute_overlap(triples_factory, src_ids, src_vectors, src_labels, target_ids, target_vectors, target_vectors_labels, threshold=0.99)
# Out:
# Subjects 'src_vectors_np' shape: (3064, 6)
# Subjects 'vector_vectors_np' shape: (3793, 6)
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10147, dest: http://www.wikidata.org/entity/Q21479712, score: 0.9969
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10151, dest: http://www.wikidata.org/entity/Q555389, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10171, dest: http://www.wikidata.org/entity/Q318816, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10192, dest: http://www.wikidata.org/entity/Q21553027, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10226, dest: http://www.wikidata.org/entity/Q2093785, score: 0.9984
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10282, dest: http://www.wikidata.org/entity/Q20972674, score: 0.9981
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10316, dest: http://www.wikidata.org/entity/Q91113706, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10414, dest: http://www.wikidata.org/entity/Q2553161, score: 0.9912
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10562, dest: http://www.wikidata.org/entity/Q1394309, score: 0.9962
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10663, dest: http://www.wikidata.org/entity/Q91113706, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10681, dest: http://www.wikidata.org/entity/Q129678692, score: 0.9985
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10802, dest: http://www.wikidata.org/entity/Q106685545, score: 0.9981
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10940, dest: http://www.wikidata.org/entity/Q47457777, score: 0.9969
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10956, dest: http://www.wikidata.org/entity/Q91113706, score: 0.9995
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10969, dest: http://www.wikidata.org/entity/Q121436734, score: 0.9962
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10976, dest: http://www.wikidata.org/entity/Q2439974, score: 0.9979
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10990, dest: http://www.wikidata.org/entity/Q160422, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11015, dest: http://www.wikidata.org/entity/Q519135, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11021, dest: http://www.wikidata.org/entity/Q470588, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11049, dest: http://www.wikidata.org/entity/Q1925023, score: 0.9996
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11060, dest: http://www.wikidata.org/entity/Q59697982, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11131, dest: http://www.wikidata.org/entity/Q73625422, score: 0.9976
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11159, dest: http://www.wikidata.org/entity/Q2073063, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11190, dest: http://www.wikidata.org/entity/Q113376907, score: 0.9995
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11214, dest: http://www.wikidata.org/entity/Q318816, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11219, dest: http://www.wikidata.org/entity/Q2606821, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11221, dest: http://www.wikidata.org/entity/Q101627610, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11222, dest: http://www.wikidata.org/entity/Q12013542, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11224, dest: http://www.wikidata.org/entity/Q110082763, score: 0.9956
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11236, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9998
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11260, dest: http://www.wikidata.org/entity/Q1812135, score: 0.9985
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11293, dest: http://www.wikidata.org/entity/Q4534534, score: 0.9946
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11313, dest: http://www.wikidata.org/entity/Q1394309, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/113254, dest: http://www.wikidata.org/entity/Q1974817, score: 0.9985
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11344, dest: http://www.wikidata.org/entity/Q447182, score: 0.9971
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11397, dest: http://www.wikidata.org/entity/Q4766256, score: 0.9944
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11427, dest: http://www.wikidata.org/entity/Q16481531, score: 0.9984
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11430, dest: http://www.wikidata.org/entity/Q109997231, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11435, dest: http://www.wikidata.org/entity/Q519135, score: 0.9975
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11437, dest: http://www.wikidata.org/entity/Q962993, score: 0.9995
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11438, dest: http://www.wikidata.org/entity/Q47457777, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11463, dest: http://www.wikidata.org/entity/Q962993, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11467, dest: http://www.wikidata.org/entity/Q19688277, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11482, dest: http://www.wikidata.org/entity/Q18194686, score: 0.9995
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11485, dest: http://www.wikidata.org/entity/Q160422, score: 0.9995
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11486, dest: http://www.wikidata.org/entity/Q1886534, score: 0.9969
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11490, dest: http://www.wikidata.org/entity/Q1871910, score: 0.9976
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11540, dest: http://www.wikidata.org/entity/Q447182, score: 0.9970
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11592, dest: http://www.wikidata.org/entity/Q3151402, score: 0.9965
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11701, dest: http://www.wikidata.org/entity/Q2094359, score: 0.9983
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11702, dest: http://www.wikidata.org/entity/Q2289191, score: 0.9944
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11751, dest: http://www.wikidata.org/entity/Q1921195, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12036, dest: http://www.wikidata.org/entity/Q2094359, score: 0.9977
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12050, dest: http://www.wikidata.org/entity/Q118151642, score: 0.9963
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12081, dest: http://www.wikidata.org/entity/Q2553161, score: 0.9962
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12090, dest: http://www.wikidata.org/entity/Q110321906, score: 0.9973
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12176, dest: http://www.wikidata.org/entity/Q2094359, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/121990, dest: http://www.wikidata.org/entity/Q42424640, score: 0.9958
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/121991, dest: http://www.wikidata.org/entity/Q962993, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12263, dest: http://www.wikidata.org/entity/Q41262025, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12282, dest: http://www.wikidata.org/entity/Q604267, score: 0.9934
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12350, dest: http://www.wikidata.org/entity/Q2112601, score: 0.9911
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12384, dest: http://www.wikidata.org/entity/Q2855465, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12387, dest: http://www.wikidata.org/entity/Q15874919, score: 0.9982
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12388, dest: http://www.wikidata.org/entity/Q2437951, score: 0.9995
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12400, dest: http://www.wikidata.org/entity/Q15876820, score: 0.9985
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12407, dest: http://www.wikidata.org/entity/Q2094359, score: 0.9976
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12414, dest: http://www.wikidata.org/entity/Q59697982, score: 0.9980
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12427, dest: http://www.wikidata.org/entity/Q31209972, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12428, dest: http://www.wikidata.org/entity/Q2637384, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12429, dest: http://www.wikidata.org/entity/Q19688277, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12430, dest: http://www.wikidata.org/entity/Q1882933, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12447, dest: http://www.wikidata.org/entity/Q1882933, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12462, dest: http://www.wikidata.org/entity/Q2578109, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12463, dest: http://www.wikidata.org/entity/Q560756, score: 0.9996
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12466, dest: http://www.wikidata.org/entity/Q29045191, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12470, dest: http://www.wikidata.org/entity/Q1812135, score: 0.9978
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12473, dest: http://www.wikidata.org/entity/Q5646677, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12474, dest: http://www.wikidata.org/entity/Q59697982, score: 0.9976
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12478, dest: http://www.wikidata.org/entity/Q1394309, score: 0.9979
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12481, dest: http://www.wikidata.org/entity/Q21855997, score: 0.9980
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12486, dest: http://www.wikidata.org/entity/Q160422, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12489, dest: http://www.wikidata.org/entity/Q26271713, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12492, dest: http://www.wikidata.org/entity/Q91113706, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12494, dest: http://www.wikidata.org/entity/Q82571595, score: 0.9998
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12496, dest: http://www.wikidata.org/entity/Q77353434, score: 0.9972
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12497, dest: http://www.wikidata.org/entity/Q2673745, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12501, dest: http://www.wikidata.org/entity/Q2637384, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12502, dest: http://www.wikidata.org/entity/Q21479712, score: 0.9977
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12504, dest: http://www.wikidata.org/entity/Q126164037, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12511, dest: http://www.wikidata.org/entity/Q160422, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12519, dest: http://www.wikidata.org/entity/Q12013285, score: 0.9997
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12520, dest: http://www.wikidata.org/entity/Q59697982, score: 0.9995
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12521, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12522, dest: http://www.wikidata.org/entity/Q19688277, score: 0.9997
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/125245, dest: http://www.wikidata.org/entity/Q555389, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12530, dest: http://www.wikidata.org/entity/Q91113706, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12533, dest: http://www.wikidata.org/entity/Q962993, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12543, dest: http://www.wikidata.org/entity/Q15876820, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12546, dest: http://www.wikidata.org/entity/Q470588, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12549, dest: http://www.wikidata.org/entity/Q2497786, score: 0.9902
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12552, dest: http://www.wikidata.org/entity/Q21081049, score: 0.9982
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12557, dest: http://www.wikidata.org/entity/Q111459370, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12561, dest: http://www.wikidata.org/entity/Q2570404, score: 0.9981
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12562, dest: http://www.wikidata.org/entity/Q28080026, score: 0.9978
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12610, dest: http://www.wikidata.org/entity/Q536951, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12615, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/126768, dest: http://www.wikidata.org/entity/Q962993, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12717, dest: http://www.wikidata.org/entity/Q2464594, score: 0.9975
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12721, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12723, dest: http://www.wikidata.org/entity/Q50091912, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12728, dest: http://www.wikidata.org/entity/Q12013542, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12739, dest: http://www.wikidata.org/entity/Q62019034, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12742, dest: http://www.wikidata.org/entity/Q129678692, score: 0.9996
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12747, dest: http://www.wikidata.org/entity/Q129678692, score: 0.9996
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/127478, dest: http://www.wikidata.org/entity/Q2740854, score: 0.9979
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12750, dest: http://www.wikidata.org/entity/Q2166558, score: 0.9971
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12752, dest: http://www.wikidata.org/entity/Q2553161, score: 0.9978
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12754, dest: http://www.wikidata.org/entity/Q2553161, score: 0.9979
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12756, dest: http://www.wikidata.org/entity/Q1913492, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12760, dest: http://www.wikidata.org/entity/Q52156973, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/127876, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12814, dest: http://www.wikidata.org/entity/Q2553161, score: 0.9981
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12822, dest: http://www.wikidata.org/entity/Q26271713, score: 0.9968
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12841, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/128479, dest: http://www.wikidata.org/entity/Q21479712, score: 0.9981
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12865, dest: http://www.wikidata.org/entity/Q1397864, score: 0.9982
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12868, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12937, dest: http://www.wikidata.org/entity/Q113376907, score: 0.9948
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12941, dest: http://www.wikidata.org/entity/Q2363980, score: 0.9959
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12952, dest: http://www.wikidata.org/entity/Q2855465, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12953, dest: http://www.wikidata.org/entity/Q555389, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12961, dest: http://www.wikidata.org/entity/Q2439974, score: 0.9996
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12963, dest: http://www.wikidata.org/entity/Q107363638, score: 0.9933
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12969, dest: http://www.wikidata.org/entity/Q1871910, score: 0.9972
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12970, dest: http://www.wikidata.org/entity/Q174655, score: 0.9985
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12990, dest: http://www.wikidata.org/entity/Q2073063, score: 0.9995
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12995, dest: http://www.wikidata.org/entity/Q59697982, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12999, dest: http://www.wikidata.org/entity/Q29415105, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13006, dest: http://www.wikidata.org/entity/Q12013542, score: 0.9997
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13008, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13010, dest: http://www.wikidata.org/entity/Q22342989, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13013, dest: http://www.wikidata.org/entity/Q24412871, score: 0.9998
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13020, dest: http://www.wikidata.org/entity/Q26211873, score: 0.9963
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13026, dest: http://www.wikidata.org/entity/Q19688277, score: 0.9985
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13027, dest: http://www.wikidata.org/entity/Q2679359, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13028, dest: http://www.wikidata.org/entity/Q962993, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13040, dest: http://www.wikidata.org/entity/Q2606821, score: 0.9907
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13041, dest: http://www.wikidata.org/entity/Q15876820, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13045, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13047, dest: http://www.wikidata.org/entity/Q318816, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13051, dest: http://www.wikidata.org/entity/Q41026476, score: 0.9998
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13054, dest: http://www.wikidata.org/entity/Q126484890, score: 0.9965
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13074, dest: http://www.wikidata.org/entity/Q2422409, score: 0.9902
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13077, dest: http://www.wikidata.org/entity/Q112259313, score: 0.9929
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13079, dest: http://www.wikidata.org/entity/Q19688277, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13085, dest: http://www.wikidata.org/entity/Q19688277, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13086, dest: http://www.wikidata.org/entity/Q555389, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13092, dest: http://www.wikidata.org/entity/Q2437951, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13099, dest: http://www.wikidata.org/entity/Q2093785, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13105, dest: http://www.wikidata.org/entity/Q519135, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13118, dest: http://www.wikidata.org/entity/Q109938674, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13198, dest: http://www.wikidata.org/entity/Q27830475, score: 0.9977
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13199, dest: http://www.wikidata.org/entity/Q2966524, score: 0.9943
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13203, dest: http://www.wikidata.org/entity/Q15876820, score: 0.9996
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13206, dest: http://www.wikidata.org/entity/Q2591418, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13207, dest: http://www.wikidata.org/entity/Q12013285, score: 0.9978
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13209, dest: http://www.wikidata.org/entity/Q19688277, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13210, dest: http://www.wikidata.org/entity/Q111444731, score: 0.9998
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13213, dest: http://www.wikidata.org/entity/Q19688277, score: 0.9996
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13218, dest: http://www.wikidata.org/entity/Q109938674, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13220, dest: http://www.wikidata.org/entity/Q2066496, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13223, dest: http://www.wikidata.org/entity/Q1882933, score: 0.9999
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13225, dest: http://www.wikidata.org/entity/Q77353434, score: 0.9943
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13229, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13231, dest: http://www.wikidata.org/entity/Q130647298, score: 0.9983
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13242, dest: http://www.wikidata.org/entity/Q1886534, score: 0.9979
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13243, dest: http://www.wikidata.org/entity/Q2073063, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13244, dest: http://www.wikidata.org/entity/Q20006066, score: 0.9929
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13245, dest: http://www.wikidata.org/entity/Q104958474, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13249, dest: http://www.wikidata.org/entity/Q16481531, score: 0.9998
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13250, dest: http://www.wikidata.org/entity/Q1871910, score: 0.9928
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13252, dest: http://www.wikidata.org/entity/Q12013542, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13253, dest: http://www.wikidata.org/entity/Q19688277, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13277, dest: http://www.wikidata.org/entity/Q26271713, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13278, dest: http://www.wikidata.org/entity/Q59697982, score: 0.9953
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13279, dest: http://www.wikidata.org/entity/Q26271713, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13297, dest: http://www.wikidata.org/entity/Q59697982, score: 0.9983
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13299, dest: http://www.wikidata.org/entity/Q29045191, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13301, dest: http://www.wikidata.org/entity/Q962993, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13303, dest: http://www.wikidata.org/entity/Q2105882, score: 0.9984
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13304, dest: http://www.wikidata.org/entity/Q555389, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13305, dest: http://www.wikidata.org/entity/Q555389, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13308, dest: http://www.wikidata.org/entity/Q13134587, score: 0.9977
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13312, dest: http://www.wikidata.org/entity/Q21553027, score: 0.9995
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13319, dest: http://www.wikidata.org/entity/Q2637384, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13322, dest: http://www.wikidata.org/entity/Q109938674, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13325, dest: http://www.wikidata.org/entity/Q1921195, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13332, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9995
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13340, dest: http://www.wikidata.org/entity/Q2855465, score: 0.9984
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13348, dest: http://www.wikidata.org/entity/Q12013542, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13349, dest: http://www.wikidata.org/entity/Q1882933, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13350, dest: http://www.wikidata.org/entity/Q107363638, score: 0.9968
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13352, dest: http://www.wikidata.org/entity/Q2497786, score: 0.9961
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13356, dest: http://www.wikidata.org/entity/Q2637384, score: 0.9978
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13360, dest: http://www.wikidata.org/entity/Q536951, score: 0.9967
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13363, dest: http://www.wikidata.org/entity/Q21479712, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13366, dest: http://www.wikidata.org/entity/Q1921195, score: 0.9997
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13368, dest: http://www.wikidata.org/entity/Q12013542, score: 0.9985
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13369, dest: http://www.wikidata.org/entity/Q18516809, score: 0.9944
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13372, dest: http://www.wikidata.org/entity/Q2343542, score: 0.9931
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13374, dest: http://www.wikidata.org/entity/Q20901597, score: 0.9967
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13378, dest: http://www.wikidata.org/entity/Q12013542, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13379, dest: http://www.wikidata.org/entity/Q962993, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13380, dest: http://www.wikidata.org/entity/Q2073063, score: 0.9996
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13396, dest: http://www.wikidata.org/entity/Q109938674, score: 0.9929
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13401, dest: http://www.wikidata.org/entity/Q555389, score: 0.9976
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13404, dest: http://www.wikidata.org/entity/Q519135, score: 0.9984
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13406, dest: http://www.wikidata.org/entity/Q29552420, score: 0.9973
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13407, dest: http://www.wikidata.org/entity/Q42424640, score: 0.9976
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13408, dest: http://www.wikidata.org/entity/Q21479712, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13409, dest: http://www.wikidata.org/entity/Q91113706, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13412, dest: http://www.wikidata.org/entity/Q1865834, score: 0.9984
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13413, dest: http://www.wikidata.org/entity/Q2966524, score: 0.9958
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13419, dest: http://www.wikidata.org/entity/Q20901597, score: 0.9998
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13422, dest: http://www.wikidata.org/entity/Q12013542, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13426, dest: http://www.wikidata.org/entity/Q130647298, score: 0.9958
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13427, dest: http://www.wikidata.org/entity/Q2740854, score: 0.9979
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13433, dest: http://www.wikidata.org/entity/Q29552420, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13436, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9996
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13437, dest: http://www.wikidata.org/entity/Q447182, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13438, dest: http://www.wikidata.org/entity/Q13640639, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13441, dest: http://www.wikidata.org/entity/Q12013542, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13442, dest: http://www.wikidata.org/entity/Q22001951, score: 0.9963
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13443, dest: http://www.wikidata.org/entity/Q12013542, score: 0.9977
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13447, dest: http://www.wikidata.org/entity/Q529366, score: 0.9997
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13448, dest: http://www.wikidata.org/entity/Q962993, score: 0.9996
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13453, dest: http://www.wikidata.org/entity/Q2570404, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13514, dest: http://www.wikidata.org/entity/Q519135, score: 0.9964
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/135528, dest: http://www.wikidata.org/entity/Q2073063, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13563, dest: http://www.wikidata.org/entity/Q2381464, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13571, dest: http://www.wikidata.org/entity/Q962993, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13586, dest: http://www.wikidata.org/entity/Q109981576, score: 0.9951
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13597, dest: http://www.wikidata.org/entity/Q126173977, score: 0.9936
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/135990, dest: http://www.wikidata.org/entity/Q29045191, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13601, dest: http://www.wikidata.org/entity/Q1921195, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13603, dest: http://www.wikidata.org/entity/Q2443132, score: 0.9963
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13637, dest: http://www.wikidata.org/entity/Q59697982, score: 0.9972
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/136757, dest: http://www.wikidata.org/entity/Q1812135, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13683, dest: http://www.wikidata.org/entity/Q962993, score: 0.9979
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13695, dest: http://www.wikidata.org/entity/Q2757640, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13700, dest: http://www.wikidata.org/entity/Q1812135, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13705, dest: http://www.wikidata.org/entity/Q113016422, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13706, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13713, dest: http://www.wikidata.org/entity/Q4534534, score: 0.9914
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13716, dest: http://www.wikidata.org/entity/Q12013542, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13726, dest: http://www.wikidata.org/entity/Q2116566, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13731, dest: http://www.wikidata.org/entity/Q21553027, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13732, dest: http://www.wikidata.org/entity/Q82571595, score: 0.9995
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13733, dest: http://www.wikidata.org/entity/Q1889934, score: 0.9954
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13737, dest: http://www.wikidata.org/entity/Q444571, score: 0.9932
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13738, dest: http://www.wikidata.org/entity/Q21855997, score: 0.9985
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13739, dest: http://www.wikidata.org/entity/Q2343542, score: 0.9967
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13741, dest: http://www.wikidata.org/entity/Q60640727, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13750, dest: http://www.wikidata.org/entity/Q555389, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13760, dest: http://www.wikidata.org/entity/Q470588, score: 0.9927
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13761, dest: http://www.wikidata.org/entity/Q123402663, score: 0.9976
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13762, dest: http://www.wikidata.org/entity/Q2949193, score: 0.9956
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13777, dest: http://www.wikidata.org/entity/Q1871910, score: 0.9937
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13779, dest: http://www.wikidata.org/entity/Q21479712, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13780, dest: http://www.wikidata.org/entity/Q555389, score: 0.9997
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13785, dest: http://www.wikidata.org/entity/Q4534534, score: 0.9945
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13787, dest: http://www.wikidata.org/entity/Q1812135, score: 0.9996
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13793, dest: http://www.wikidata.org/entity/Q560756, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13794, dest: http://www.wikidata.org/entity/Q1886534, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13795, dest: http://www.wikidata.org/entity/Q160422, score: 0.9982
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13838, dest: http://www.wikidata.org/entity/Q1812135, score: 0.9979
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13933, dest: http://www.wikidata.org/entity/Q160422, score: 0.9979
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13936, dest: http://www.wikidata.org/entity/Q962993, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13938, dest: http://www.wikidata.org/entity/Q21479712, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13942, dest: http://www.wikidata.org/entity/Q4771266, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13947, dest: http://www.wikidata.org/entity/Q21479712, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13952, dest: http://www.wikidata.org/entity/Q16481531, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13965, dest: http://www.wikidata.org/entity/Q59697982, score: 0.9968
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13969, dest: http://www.wikidata.org/entity/Q111971402, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13982, dest: http://www.wikidata.org/entity/Q962993, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13985, dest: http://www.wikidata.org/entity/Q2343542, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13996, dest: http://www.wikidata.org/entity/Q519135, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/140346, dest: http://www.wikidata.org/entity/Q2116566, score: 0.9975
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14065, dest: http://www.wikidata.org/entity/Q129678692, score: 0.9997
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14089, dest: http://www.wikidata.org/entity/Q12013542, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14102, dest: http://www.wikidata.org/entity/Q15876820, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14117, dest: http://www.wikidata.org/entity/Q555389, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14139, dest: http://www.wikidata.org/entity/Q7848367, score: 0.9934
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14149, dest: http://www.wikidata.org/entity/Q19688277, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14150, dest: http://www.wikidata.org/entity/Q2422409, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14153, dest: http://www.wikidata.org/entity/Q12013542, score: 0.9980
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14156, dest: http://www.wikidata.org/entity/Q126164037, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14157, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14159, dest: http://www.wikidata.org/entity/Q2464594, score: 0.9966
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14160, dest: http://www.wikidata.org/entity/Q106685545, score: 0.9972
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14161, dest: http://www.wikidata.org/entity/Q16481531, score: 0.9982
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14164, dest: http://www.wikidata.org/entity/Q2949193, score: 0.9980
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14166, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9995
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14167, dest: http://www.wikidata.org/entity/Q106685600, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14185, dest: http://www.wikidata.org/entity/Q105885185, score: 0.9940
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14191, dest: http://www.wikidata.org/entity/Q1882933, score: 0.9996
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14197, dest: http://www.wikidata.org/entity/Q21553027, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14230, dest: http://www.wikidata.org/entity/Q1871910, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14232, dest: http://www.wikidata.org/entity/Q59697982, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14239, dest: http://www.wikidata.org/entity/Q519135, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14253, dest: http://www.wikidata.org/entity/Q470588, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14305, dest: http://www.wikidata.org/entity/Q708333, score: 0.9950
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14430, dest: http://www.wikidata.org/entity/Q1882933, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14431, dest: http://www.wikidata.org/entity/Q519135, score: 0.9984
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14433, dest: http://www.wikidata.org/entity/Q519135, score: 0.9950
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14436, dest: http://www.wikidata.org/entity/Q2606821, score: 0.9970
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14470, dest: http://www.wikidata.org/entity/Q26271713, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14516, dest: http://www.wikidata.org/entity/Q12013542, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14640, dest: http://www.wikidata.org/entity/Q118151642, score: 0.9975
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14655, dest: http://www.wikidata.org/entity/Q107363638, score: 0.9951
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14668, dest: http://www.wikidata.org/entity/Q2094359, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14685, dest: http://www.wikidata.org/entity/Q41262025, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14686, dest: http://www.wikidata.org/entity/Q65426322, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14694, dest: http://www.wikidata.org/entity/Q15876820, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14754, dest: http://www.wikidata.org/entity/Q15876820, score: 0.9998
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14777, dest: http://www.wikidata.org/entity/Q91113706, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14788, dest: http://www.wikidata.org/entity/Q160422, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14795, dest: http://www.wikidata.org/entity/Q2865152, score: 0.9996
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14839, dest: http://www.wikidata.org/entity/Q2949193, score: 0.9973
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14856, dest: http://www.wikidata.org/entity/Q470588, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14890, dest: http://www.wikidata.org/entity/Q2855465, score: 0.9977
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14892, dest: http://www.wikidata.org/entity/Q962993, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14894, dest: http://www.wikidata.org/entity/Q2513330, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14905, dest: http://www.wikidata.org/entity/Q2073991, score: 0.9983
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14906, dest: http://www.wikidata.org/entity/Q25973460, score: 0.9978
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14962, dest: http://www.wikidata.org/entity/Q69648868, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14976, dest: http://www.wikidata.org/entity/Q4534534, score: 0.9964
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14984, dest: http://www.wikidata.org/entity/Q318816, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14991, dest: http://www.wikidata.org/entity/Q29552420, score: 0.9995
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15151, dest: http://www.wikidata.org/entity/Q29045191, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15168, dest: http://www.wikidata.org/entity/Q91113706, score: 0.9996
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/151784, dest: http://www.wikidata.org/entity/Q20857319, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15209, dest: http://www.wikidata.org/entity/Q1583336, score: 0.9931
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/152127, dest: http://www.wikidata.org/entity/Q30112459, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15213, dest: http://www.wikidata.org/entity/Q1932943, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/152168, dest: http://www.wikidata.org/entity/Q60272071, score: 0.9984
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/152181, dest: http://www.wikidata.org/entity/Q61246303, score: 0.9964
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/152225, dest: http://www.wikidata.org/entity/Q60272023, score: 0.9996
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15257, dest: http://www.wikidata.org/entity/Q4771266, score: 0.9981
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15269, dest: http://www.wikidata.org/entity/Q2149829, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/152739, dest: http://www.wikidata.org/entity/Q109981576, score: 0.9936
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15277, dest: http://www.wikidata.org/entity/Q2093785, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/152867, dest: http://www.wikidata.org/entity/Q21228265, score: 0.9973
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/152924, dest: http://www.wikidata.org/entity/Q84594157, score: 0.9981
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/152937, dest: http://www.wikidata.org/entity/Q19688277, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15295, dest: http://www.wikidata.org/entity/Q94516245, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/152959, dest: http://www.wikidata.org/entity/Q22350528, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/152978, dest: http://www.wikidata.org/entity/Q22350528, score: 0.9969
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/152993, dest: http://www.wikidata.org/entity/Q1812135, score: 0.9985
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/153266, dest: http://www.wikidata.org/entity/Q19688277, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15344, dest: http://www.wikidata.org/entity/Q2343542, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15364, dest: http://www.wikidata.org/entity/Q26271713, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/153700, dest: http://www.wikidata.org/entity/Q21479712, score: 0.9997
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/154258, dest: http://www.wikidata.org/entity/Q60006289, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15496, dest: http://www.wikidata.org/entity/Q2343542, score: 0.9976
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/154960, dest: http://www.wikidata.org/entity/Q63256588, score: 0.9944
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/155085, dest: http://www.wikidata.org/entity/Q1974817, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15523, dest: http://www.wikidata.org/entity/Q55205269, score: 0.9996
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/155648, dest: http://www.wikidata.org/entity/Q129678692, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/155673, dest: http://www.wikidata.org/entity/Q2610946, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15620, dest: http://www.wikidata.org/entity/Q62019034, score: 0.9983
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15643, dest: http://www.wikidata.org/entity/Q109981576, score: 0.9969
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15660, dest: http://www.wikidata.org/entity/Q109981576, score: 0.9960
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15669, dest: http://www.wikidata.org/entity/Q47457777, score: 0.9983
# ...
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52763, dest: http://www.wikidata.org/entity/Q2093785, score: 0.9953
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52841, dest: http://www.wikidata.org/entity/Q106685600, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52842, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9984
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52847, dest: http://www.wikidata.org/entity/Q73625422, score: 0.9949
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52870, dest: http://www.wikidata.org/entity/Q1812135, score: 0.9998
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52895, dest: http://www.wikidata.org/entity/Q447182, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52896, dest: http://www.wikidata.org/entity/Q2073063, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52919, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52921, dest: http://www.wikidata.org/entity/Q21479712, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52930, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52964, dest: http://www.wikidata.org/entity/Q2363980, score: 0.9964
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53018, dest: http://www.wikidata.org/entity/Q3908589, score: 0.9982
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53031, dest: http://www.wikidata.org/entity/Q7848367, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53037, dest: http://www.wikidata.org/entity/Q12013542, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53042, dest: http://www.wikidata.org/entity/Q59697982, score: 0.9983
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53062, dest: http://www.wikidata.org/entity/Q1865834, score: 0.9984
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53070, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53096, dest: http://www.wikidata.org/entity/Q708333, score: 0.9935
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53113, dest: http://www.wikidata.org/entity/Q519135, score: 0.9999
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53133, dest: http://www.wikidata.org/entity/Q21553027, score: 0.9996
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53213, dest: http://www.wikidata.org/entity/Q2073063, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53253, dest: http://www.wikidata.org/entity/Q2570404, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53265, dest: http://www.wikidata.org/entity/Q708333, score: 0.9943
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53280, dest: http://www.wikidata.org/entity/Q21553027, score: 0.9961
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53285, dest: http://www.wikidata.org/entity/Q1921195, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53291, dest: http://www.wikidata.org/entity/Q98844730, score: 0.9948
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53329, dest: http://www.wikidata.org/entity/Q7848367, score: 0.9983
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53342, dest: http://www.wikidata.org/entity/Q2073063, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53373, dest: http://www.wikidata.org/entity/Q1697966, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53442, dest: http://www.wikidata.org/entity/Q555389, score: 0.9973
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54127, dest: http://www.wikidata.org/entity/Q555389, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54170, dest: http://www.wikidata.org/entity/Q15876820, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54269, dest: http://www.wikidata.org/entity/Q26271713, score: 0.9960
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54275, dest: http://www.wikidata.org/entity/Q160422, score: 0.9980
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54305, dest: http://www.wikidata.org/entity/Q962993, score: 0.9981
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54326, dest: http://www.wikidata.org/entity/Q318816, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54451, dest: http://www.wikidata.org/entity/Q2865152, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54489, dest: http://www.wikidata.org/entity/Q5646677, score: 0.9983
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54547, dest: http://www.wikidata.org/entity/Q31209972, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54604, dest: http://www.wikidata.org/entity/Q1913492, score: 0.9985
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54632, dest: http://www.wikidata.org/entity/Q1394309, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54633, dest: http://www.wikidata.org/entity/Q91113706, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54755, dest: http://www.wikidata.org/entity/Q21479712, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54760, dest: http://www.wikidata.org/entity/Q101627610, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54801, dest: http://www.wikidata.org/entity/Q82571595, score: 0.9995
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54849, dest: http://www.wikidata.org/entity/Q1921195, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54853, dest: http://www.wikidata.org/entity/Q19688277, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54867, dest: http://www.wikidata.org/entity/Q529366, score: 0.9985
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54881, dest: http://www.wikidata.org/entity/Q21553027, score: 0.9995
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54915, dest: http://www.wikidata.org/entity/Q91113706, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54985, dest: http://www.wikidata.org/entity/Q19574364, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/55001, dest: http://www.wikidata.org/entity/Q62019034, score: 0.9984
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/55064, dest: http://www.wikidata.org/entity/Q31209972, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/55282, dest: http://www.wikidata.org/entity/Q160422, score: 0.9985
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/55326, dest: http://www.wikidata.org/entity/Q2094359, score: 0.9972
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/55366, dest: http://www.wikidata.org/entity/Q19688277, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/56484, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/57008, dest: http://www.wikidata.org/entity/Q1898593, score: 0.9960
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/58168, dest: http://www.wikidata.org/entity/Q708333, score: 0.9979
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/58171, dest: http://www.wikidata.org/entity/Q1882933, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/58322, dest: http://www.wikidata.org/entity/Q1394309, score: 0.9981
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/58793, dest: http://www.wikidata.org/entity/Q15876820, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/59266, dest: http://www.wikidata.org/entity/Q1886534, score: 0.9985
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/59268, dest: http://www.wikidata.org/entity/Q15876820, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/59406, dest: http://www.wikidata.org/entity/Q28080026, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/59930, dest: http://www.wikidata.org/entity/Q126164037, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/60584, dest: http://www.wikidata.org/entity/Q2570404, score: 0.9980
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/60681, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/61542, dest: http://www.wikidata.org/entity/Q25973460, score: 0.9956
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/62222, dest: http://www.wikidata.org/entity/Q1882933, score: 0.9970
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/62349, dest: http://www.wikidata.org/entity/Q4771266, score: 0.9958
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/62751, dest: http://www.wikidata.org/entity/Q1882933, score: 0.9985
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/62991, dest: http://www.wikidata.org/entity/Q59245595, score: 0.9976
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/63089, dest: http://www.wikidata.org/entity/Q109938674, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/63144, dest: http://www.wikidata.org/entity/Q447182, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/63350, dest: http://www.wikidata.org/entity/Q31209972, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/63797, dest: http://www.wikidata.org/entity/Q160422, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/64352, dest: http://www.wikidata.org/entity/Q2553161, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/64796, dest: http://www.wikidata.org/entity/Q108751480, score: 0.9970
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/65587, dest: http://www.wikidata.org/entity/Q1913492, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/65750, dest: http://www.wikidata.org/entity/Q2275652, score: 0.9925
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/66140, dest: http://www.wikidata.org/entity/Q962993, score: 0.9995
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/66359, dest: http://www.wikidata.org/entity/Q318816, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/67112, dest: http://www.wikidata.org/entity/Q2105882, score: 0.9995
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/67115, dest: http://www.wikidata.org/entity/Q19688277, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/67862, dest: http://www.wikidata.org/entity/Q962993, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/68688, dest: http://www.wikidata.org/entity/Q1871910, score: 0.9938
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/68855, dest: http://www.wikidata.org/entity/Q20901597, score: 0.9998
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/68865, dest: http://www.wikidata.org/entity/Q12013542, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/69338, dest: http://www.wikidata.org/entity/Q91113706, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/69406, dest: http://www.wikidata.org/entity/Q2073063, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/69682, dest: http://www.wikidata.org/entity/Q708333, score: 0.9965
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/69683, dest: http://www.wikidata.org/entity/Q123698555, score: 0.9971
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/69999, dest: http://www.wikidata.org/entity/Q2726659, score: 0.9922
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/70024, dest: http://www.wikidata.org/entity/Q2116566, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/70083, dest: http://www.wikidata.org/entity/Q2073063, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/70252, dest: http://www.wikidata.org/entity/Q1394697, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/70395, dest: http://www.wikidata.org/entity/Q470588, score: 0.9983
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/70907, dest: http://www.wikidata.org/entity/Q65561542, score: 0.9998
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/71072, dest: http://www.wikidata.org/entity/Q41026476, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/71282, dest: http://www.wikidata.org/entity/Q21997287, score: 0.9969
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/71665, dest: http://www.wikidata.org/entity/Q1913492, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/71762, dest: http://www.wikidata.org/entity/Q1892514, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/71763, dest: http://www.wikidata.org/entity/Q1951369, score: 0.9985
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/71951, dest: http://www.wikidata.org/entity/Q2747033, score: 0.9969
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/71997, dest: http://www.wikidata.org/entity/Q2553161, score: 0.9995
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/72575, dest: http://www.wikidata.org/entity/Q3908589, score: 0.9929
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/73005, dest: http://www.wikidata.org/entity/Q13641297, score: 0.9998
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/74291, dest: http://www.wikidata.org/entity/Q61246303, score: 0.9980
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/74779, dest: http://www.wikidata.org/entity/Q519135, score: 0.9983
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/75189, dest: http://www.wikidata.org/entity/Q2591418, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/75846, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/76178, dest: http://www.wikidata.org/entity/Q113376907, score: 0.9983
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/76250, dest: http://www.wikidata.org/entity/Q15876820, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/77269, dest: http://www.wikidata.org/entity/Q42424640, score: 0.9948
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/78323, dest: http://www.wikidata.org/entity/Q642072, score: 0.9982
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/80473, dest: http://www.wikidata.org/entity/Q555389, score: 0.9995
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/83415, dest: http://www.wikidata.org/entity/Q12012418, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/84732, dest: http://www.wikidata.org/entity/Q519135, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/88217, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9996
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/88454, dest: http://www.wikidata.org/entity/Q2472810, score: 0.9952
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/90089, dest: http://www.wikidata.org/entity/Q29169011, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/90841, dest: http://www.wikidata.org/entity/Q21855997, score: 0.9998
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/92109, dest: http://www.wikidata.org/entity/Q60270006, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/93867, dest: http://www.wikidata.org/entity/Q59697982, score: 0.9975
# Highest Similarity Score: 0.9999582767486572

# %% [markdown]
# ### Construct Validation Sheet of this round

# %%
def creat_validation_sheet(sheet_path, matches_dict, src_triples, target_triples):
    data = {} # where we feed it to a Dataframe
    # create validation sheet based on similar_wiki_pairs_dict entries
    for k, v in matches_dict.items():
        s, d = k[0], k[1]
        sim = v
                        
        data['s'] =  data.get('s', []) + [s]    
      
        probs_s = get_record(src_triples, s)
        for pk, pv in probs_s.items():
            if pk == 'name':
                data[pk] = data.get(pk, []) + [pv]
            
        data['d'] =  data.get('d', []) + [d]
    
    
        probs_d = get_record(target_triples, d)
        for pk, pv in probs_d.items():        
            if  'name' in pk:
                data[f"{pk}.1"] = data.get(f"{pk}.1", []) + [pv]
    
        data['sim'] = data.get('sim', []) + [round(sim, 2)]
    df = pd.DataFrame.from_dict(data, orient='columns', dtype='str')
    df.head(10)
    df.to_csv(sheet_path, index=False)
    print(f'saved to {sheet_path} ...')

# %%
validation_path = join(config.validation_sheets_path, 'NIxWikidata.csv')

# %%
creat_validation_sheet(validation_path, similar_wiki_pairs_dict, ni_etl_obj.triples, wikidata_etl_obj.triples)
# Out:
# saved to /home/muhammad/Downloads/LOD-Linker/results/validation/NIxWikidata.csv ...

# %% [markdown]
# ### RKD Similartiy

# %%
target_ids = triples_factory.entities_to_ids([s for s in rkd_etl_obj.subjects])

# %%
target_vectors = embeddings_entity_np[target_ids]

# %%
target_vectors.shape
# Out:
# (4331, 6)

# %%
target_vectors_labels =[s for s in rkd_etl_obj.subjects]

# %%
handle_similarity(src_vectors, target_vectors, src_labels, target_vectors_labels, annotate=False)

# %%
similar_rkd_pairs_dict = compute_overlap(triples_factory, src_ids, src_vectors, src_labels, target_ids, target_vectors, target_vectors_labels, threshold=0.98)
# Out:
# Subjects 'src_vectors_np' shape: (3064, 6)
# Subjects 'vector_vectors_np' shape: (4331, 6)
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10147, dest: https://data.rkd.nl/artists/134841, score: 0.9960
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10151, dest: https://data.rkd.nl/artists/212582, score: 0.9838
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10171, dest: https://data.rkd.nl/artists/66525, score: 0.9905
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10192, dest: https://data.rkd.nl/artists/338058, score: 0.9973
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10226, dest: https://data.rkd.nl/artists/388601, score: 0.9821
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10282, dest: https://data.rkd.nl/artists/370297, score: 0.9801
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10316, dest: https://data.rkd.nl/artists/212582, score: 0.9967
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10414, dest: https://data.rkd.nl/artists/304342, score: 0.9914
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10562, dest: https://data.rkd.nl/artists/212582, score: 0.9805
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10663, dest: https://data.rkd.nl/artists/338058, score: 0.9941
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10681, dest: https://data.rkd.nl/artists/134841, score: 0.9893
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10802, dest: https://data.rkd.nl/artists/93178, score: 0.9880
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10862, dest: https://data.rkd.nl/artists/388601, score: 0.9843
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10905, dest: https://data.rkd.nl/artists/281159, score: 0.9962
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10940, dest: https://data.rkd.nl/artists/134841, score: 0.9928
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10956, dest: https://data.rkd.nl/artists/338058, score: 0.9940
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10976, dest: https://data.rkd.nl/artists/131165, score: 0.9979
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/10990, dest: https://data.rkd.nl/artists/232076, score: 0.9913
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11015, dest: https://data.rkd.nl/artists/279595, score: 0.9883
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11021, dest: https://data.rkd.nl/artists/233340, score: 0.9991
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11049, dest: https://data.rkd.nl/artists/132409, score: 0.9980
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11060, dest: https://data.rkd.nl/artists/267462, score: 0.9862
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11131, dest: https://data.rkd.nl/artists/1785, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11159, dest: https://data.rkd.nl/artists/212582, score: 0.9953
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11190, dest: https://data.rkd.nl/artists/388601, score: 0.9936
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11214, dest: https://data.rkd.nl/artists/132409, score: 0.9954
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11219, dest: https://data.rkd.nl/artists/116471, score: 0.9862
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11221, dest: https://data.rkd.nl/artists/134841, score: 0.9870
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11222, dest: https://data.rkd.nl/artists/134841, score: 0.9913
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11224, dest: https://data.rkd.nl/artists/370297, score: 0.9824
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11236, dest: https://data.rkd.nl/artists/134841, score: 0.9898
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11260, dest: https://data.rkd.nl/artists/233340, score: 0.9936
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11293, dest: https://data.rkd.nl/artists/388601, score: 0.9922
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11313, dest: https://data.rkd.nl/artists/212582, score: 0.9895
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11344, dest: https://data.rkd.nl/artists/233340, score: 0.9976
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11397, dest: https://data.rkd.nl/artists/463373, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11427, dest: https://data.rkd.nl/artists/134841, score: 0.9869
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11435, dest: https://data.rkd.nl/artists/388601, score: 0.9934
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11437, dest: https://data.rkd.nl/artists/454488, score: 0.9951
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11438, dest: https://data.rkd.nl/artists/267462, score: 0.9947
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11463, dest: https://data.rkd.nl/artists/212582, score: 0.9974
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11467, dest: https://data.rkd.nl/artists/212582, score: 0.9900
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11482, dest: https://data.rkd.nl/artists/212582, score: 0.9816
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11485, dest: https://data.rkd.nl/artists/232076, score: 0.9958
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11486, dest: https://data.rkd.nl/artists/267462, score: 0.9970
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11490, dest: https://data.rkd.nl/artists/134841, score: 0.9912
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11540, dest: https://data.rkd.nl/artists/233136, score: 0.9978
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11592, dest: https://data.rkd.nl/artists/282749, score: 0.9980
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11701, dest: https://data.rkd.nl/artists/232076, score: 0.9972
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/11751, dest: https://data.rkd.nl/artists/212582, score: 0.9936
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12036, dest: https://data.rkd.nl/artists/232076, score: 0.9981
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12081, dest: https://data.rkd.nl/artists/279595, score: 0.9919
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12090, dest: https://data.rkd.nl/artists/110454, score: 0.9905
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12176, dest: https://data.rkd.nl/artists/131165, score: 0.9949
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/121990, dest: https://data.rkd.nl/artists/267189, score: 0.9952
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/121991, dest: https://data.rkd.nl/artists/212582, score: 0.9947
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12263, dest: https://data.rkd.nl/artists/370297, score: 0.9891
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12350, dest: https://data.rkd.nl/artists/381502, score: 0.9966
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12384, dest: https://data.rkd.nl/artists/388601, score: 0.9922
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12387, dest: https://data.rkd.nl/artists/373053, score: 0.9961
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12388, dest: https://data.rkd.nl/artists/14418, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12400, dest: https://data.rkd.nl/artists/212582, score: 0.9922
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12407, dest: https://data.rkd.nl/artists/131165, score: 0.9977
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12414, dest: https://data.rkd.nl/artists/370297, score: 0.9933
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12427, dest: https://data.rkd.nl/artists/132409, score: 0.9966
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12428, dest: https://data.rkd.nl/artists/132409, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12429, dest: https://data.rkd.nl/artists/134841, score: 0.9916
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12430, dest: https://data.rkd.nl/artists/132409, score: 0.9960
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12447, dest: https://data.rkd.nl/artists/66525, score: 0.9975
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12463, dest: https://data.rkd.nl/artists/279595, score: 0.9953
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12466, dest: https://data.rkd.nl/artists/212582, score: 0.9902
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12470, dest: https://data.rkd.nl/artists/212582, score: 0.9971
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12473, dest: https://data.rkd.nl/artists/134841, score: 0.9960
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12474, dest: https://data.rkd.nl/artists/267462, score: 0.9952
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12478, dest: https://data.rkd.nl/artists/212582, score: 0.9902
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12481, dest: https://data.rkd.nl/artists/212582, score: 0.9974
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12486, dest: https://data.rkd.nl/artists/232076, score: 0.9900
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12492, dest: https://data.rkd.nl/artists/338058, score: 0.9912
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12494, dest: https://data.rkd.nl/artists/212582, score: 0.9899
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12496, dest: https://data.rkd.nl/artists/388601, score: 0.9917
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12497, dest: https://data.rkd.nl/artists/93178, score: 0.9931
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12501, dest: https://data.rkd.nl/artists/7938, score: 0.9996
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12502, dest: https://data.rkd.nl/artists/134841, score: 0.9925
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12504, dest: https://data.rkd.nl/artists/134841, score: 0.9892
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12511, dest: https://data.rkd.nl/artists/134841, score: 0.9944
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12519, dest: https://data.rkd.nl/artists/88778, score: 0.9975
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12520, dest: https://data.rkd.nl/artists/267462, score: 0.9897
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12521, dest: https://data.rkd.nl/artists/212582, score: 0.9865
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12522, dest: https://data.rkd.nl/artists/134841, score: 0.9894
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/125245, dest: https://data.rkd.nl/artists/134841, score: 0.9924
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12530, dest: https://data.rkd.nl/artists/212582, score: 0.9951
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12533, dest: https://data.rkd.nl/artists/212582, score: 0.9934
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12543, dest: https://data.rkd.nl/artists/66525, score: 0.9922
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12546, dest: https://data.rkd.nl/artists/233340, score: 0.9978
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12557, dest: https://data.rkd.nl/artists/88401, score: 0.9851
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12561, dest: https://data.rkd.nl/artists/212582, score: 0.9883
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12562, dest: https://data.rkd.nl/artists/265206, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12603, dest: https://data.rkd.nl/artists/267462, score: 0.9840
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12610, dest: https://data.rkd.nl/artists/93178, score: 0.9910
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12615, dest: https://data.rkd.nl/artists/134841, score: 0.9899
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/126768, dest: https://data.rkd.nl/artists/134841, score: 0.9955
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12717, dest: https://data.rkd.nl/artists/279595, score: 0.9941
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12721, dest: https://data.rkd.nl/artists/212582, score: 0.9920
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12723, dest: https://data.rkd.nl/artists/212582, score: 0.9821
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12728, dest: https://data.rkd.nl/artists/134841, score: 0.9875
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12739, dest: https://data.rkd.nl/artists/132409, score: 0.9981
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12742, dest: https://data.rkd.nl/artists/134841, score: 0.9867
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12747, dest: https://data.rkd.nl/artists/134841, score: 0.9850
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/127478, dest: https://data.rkd.nl/artists/212582, score: 0.9929
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12750, dest: https://data.rkd.nl/artists/370297, score: 0.9842
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12752, dest: https://data.rkd.nl/artists/388601, score: 0.9889
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12754, dest: https://data.rkd.nl/artists/304342, score: 0.9960
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12756, dest: https://data.rkd.nl/artists/212582, score: 0.9947
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/127876, dest: https://data.rkd.nl/artists/212582, score: 0.9933
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12814, dest: https://data.rkd.nl/artists/304342, score: 0.9924
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12822, dest: https://data.rkd.nl/artists/388601, score: 0.9906
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12841, dest: https://data.rkd.nl/artists/134841, score: 0.9920
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/128479, dest: https://data.rkd.nl/artists/134841, score: 0.9944
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12865, dest: https://data.rkd.nl/artists/454488, score: 0.9852
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12868, dest: https://data.rkd.nl/artists/134841, score: 0.9904
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12937, dest: https://data.rkd.nl/artists/388601, score: 0.9953
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12941, dest: https://data.rkd.nl/artists/370297, score: 0.9913
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12952, dest: https://data.rkd.nl/artists/388601, score: 0.9920
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12953, dest: https://data.rkd.nl/artists/212582, score: 0.9879
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12961, dest: https://data.rkd.nl/artists/131165, score: 0.9979
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12963, dest: https://data.rkd.nl/artists/370297, score: 0.9898
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12969, dest: https://data.rkd.nl/artists/134841, score: 0.9888
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12990, dest: https://data.rkd.nl/artists/212582, score: 0.9950
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12995, dest: https://data.rkd.nl/artists/267462, score: 0.9908
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/12999, dest: https://data.rkd.nl/artists/134841, score: 0.9881
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13006, dest: https://data.rkd.nl/artists/212582, score: 0.9865
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13008, dest: https://data.rkd.nl/artists/134841, score: 0.9912
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13010, dest: https://data.rkd.nl/artists/212582, score: 0.9898
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13026, dest: https://data.rkd.nl/artists/134841, score: 0.9906
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13027, dest: https://data.rkd.nl/artists/132409, score: 0.9954
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13028, dest: https://data.rkd.nl/artists/212582, score: 0.9915
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13040, dest: https://data.rkd.nl/artists/116471, score: 0.9915
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13041, dest: https://data.rkd.nl/artists/212582, score: 0.9916
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13045, dest: https://data.rkd.nl/artists/134841, score: 0.9890
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13047, dest: https://data.rkd.nl/artists/132409, score: 0.9946
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13051, dest: https://data.rkd.nl/artists/212582, score: 0.9953
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13074, dest: https://data.rkd.nl/artists/479878, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13079, dest: https://data.rkd.nl/artists/212582, score: 0.9832
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13085, dest: https://data.rkd.nl/artists/212582, score: 0.9918
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13086, dest: https://data.rkd.nl/artists/134841, score: 0.9882
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13092, dest: https://data.rkd.nl/artists/14418, score: 0.9988
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13105, dest: https://data.rkd.nl/artists/279595, score: 0.9828
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13118, dest: https://data.rkd.nl/artists/212582, score: 0.9865
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13198, dest: https://data.rkd.nl/artists/304342, score: 0.9844
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13199, dest: https://data.rkd.nl/artists/388601, score: 0.9982
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13203, dest: https://data.rkd.nl/artists/212582, score: 0.9940
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13206, dest: https://data.rkd.nl/artists/388601, score: 0.9808
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13207, dest: https://data.rkd.nl/artists/88778, score: 0.9973
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13209, dest: https://data.rkd.nl/artists/134841, score: 0.9899
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13210, dest: https://data.rkd.nl/artists/212582, score: 0.9828
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13213, dest: https://data.rkd.nl/artists/134841, score: 0.9881
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13218, dest: https://data.rkd.nl/artists/212582, score: 0.9910
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13223, dest: https://data.rkd.nl/artists/132409, score: 0.9962
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13225, dest: https://data.rkd.nl/artists/388601, score: 0.9893
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13229, dest: https://data.rkd.nl/artists/212582, score: 0.9909
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13231, dest: https://data.rkd.nl/artists/388601, score: 0.9869
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13242, dest: https://data.rkd.nl/artists/134841, score: 0.9928
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13243, dest: https://data.rkd.nl/artists/338058, score: 0.9948
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13249, dest: https://data.rkd.nl/artists/134841, score: 0.9838
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13250, dest: https://data.rkd.nl/artists/370297, score: 0.9923
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13252, dest: https://data.rkd.nl/artists/134841, score: 0.9891
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13253, dest: https://data.rkd.nl/artists/212582, score: 0.9900
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13277, dest: https://data.rkd.nl/artists/388601, score: 0.9823
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13278, dest: https://data.rkd.nl/artists/267462, score: 0.9904
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13279, dest: https://data.rkd.nl/artists/388601, score: 0.9820
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13297, dest: https://data.rkd.nl/artists/370297, score: 0.9892
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13299, dest: https://data.rkd.nl/artists/212582, score: 0.9893
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13301, dest: https://data.rkd.nl/artists/212582, score: 0.9923
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13303, dest: https://data.rkd.nl/artists/102210, score: 0.9984
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13304, dest: https://data.rkd.nl/artists/134841, score: 0.9932
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13305, dest: https://data.rkd.nl/artists/134841, score: 0.9935
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13308, dest: https://data.rkd.nl/artists/212582, score: 0.9891
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13312, dest: https://data.rkd.nl/artists/338058, score: 0.9969
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13319, dest: https://data.rkd.nl/artists/7938, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13322, dest: https://data.rkd.nl/artists/212582, score: 0.9931
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13325, dest: https://data.rkd.nl/artists/212582, score: 0.9933
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13332, dest: https://data.rkd.nl/artists/134841, score: 0.9876
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13340, dest: https://data.rkd.nl/artists/388601, score: 0.9930
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13348, dest: https://data.rkd.nl/artists/134841, score: 0.9892
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13349, dest: https://data.rkd.nl/artists/66525, score: 0.9933
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13350, dest: https://data.rkd.nl/artists/370297, score: 0.9861
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13352, dest: https://data.rkd.nl/artists/362765, score: 0.9857
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13356, dest: https://data.rkd.nl/artists/425362, score: 0.9970
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13360, dest: https://data.rkd.nl/artists/94274, score: 0.9874
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13363, dest: https://data.rkd.nl/artists/134841, score: 0.9935
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13366, dest: https://data.rkd.nl/artists/212582, score: 0.9927
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13368, dest: https://data.rkd.nl/artists/134841, score: 0.9928
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13372, dest: https://data.rkd.nl/artists/370297, score: 0.9986
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13374, dest: https://data.rkd.nl/artists/90016, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13378, dest: https://data.rkd.nl/artists/134841, score: 0.9903
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13379, dest: https://data.rkd.nl/artists/134841, score: 0.9968
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13380, dest: https://data.rkd.nl/artists/212582, score: 0.9929
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13401, dest: https://data.rkd.nl/artists/388601, score: 0.9858
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13404, dest: https://data.rkd.nl/artists/376113, score: 0.9855
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13406, dest: https://data.rkd.nl/artists/370297, score: 0.9833
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13407, dest: https://data.rkd.nl/artists/279595, score: 0.9968
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13408, dest: https://data.rkd.nl/artists/134841, score: 0.9945
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13409, dest: https://data.rkd.nl/artists/14418, score: 0.9949
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13412, dest: https://data.rkd.nl/artists/8989, score: 0.9971
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13413, dest: https://data.rkd.nl/artists/388601, score: 0.9980
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13419, dest: https://data.rkd.nl/artists/277905, score: 0.9992
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13422, dest: https://data.rkd.nl/artists/134841, score: 0.9882
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13426, dest: https://data.rkd.nl/artists/267462, score: 0.9919
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13427, dest: https://data.rkd.nl/artists/134841, score: 0.9920
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13433, dest: https://data.rkd.nl/artists/388601, score: 0.9808
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13436, dest: https://data.rkd.nl/artists/212582, score: 0.9866
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13437, dest: https://data.rkd.nl/artists/66525, score: 0.9973
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13441, dest: https://data.rkd.nl/artists/134841, score: 0.9871
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13442, dest: https://data.rkd.nl/artists/388601, score: 0.9952
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13443, dest: https://data.rkd.nl/artists/370297, score: 0.9876
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13447, dest: https://data.rkd.nl/artists/212582, score: 0.9881
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13448, dest: https://data.rkd.nl/artists/212582, score: 0.9962
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13453, dest: https://data.rkd.nl/artists/212582, score: 0.9874
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13514, dest: https://data.rkd.nl/artists/388601, score: 0.9939
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/135528, dest: https://data.rkd.nl/artists/212582, score: 0.9949
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13571, dest: https://data.rkd.nl/artists/212582, score: 0.9950
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13586, dest: https://data.rkd.nl/artists/267462, score: 0.9930
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/135990, dest: https://data.rkd.nl/artists/212582, score: 0.9919
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13601, dest: https://data.rkd.nl/artists/212582, score: 0.9920
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13603, dest: https://data.rkd.nl/artists/132409, score: 0.9847
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13637, dest: https://data.rkd.nl/artists/267462, score: 0.9939
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13671, dest: https://data.rkd.nl/artists/61769, score: 0.9873
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/136757, dest: https://data.rkd.nl/artists/212582, score: 0.9962
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13683, dest: https://data.rkd.nl/artists/134841, score: 0.9949
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13700, dest: https://data.rkd.nl/artists/233340, score: 0.9944
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13706, dest: https://data.rkd.nl/artists/134841, score: 0.9920
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13713, dest: https://data.rkd.nl/artists/388601, score: 0.9933
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13716, dest: https://data.rkd.nl/artists/134841, score: 0.9904
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13726, dest: https://data.rkd.nl/artists/232076, score: 0.9984
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13731, dest: https://data.rkd.nl/artists/338058, score: 0.9971
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13732, dest: https://data.rkd.nl/artists/212582, score: 0.9876
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13733, dest: https://data.rkd.nl/artists/370297, score: 0.9831
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13737, dest: https://data.rkd.nl/artists/267462, score: 0.9816
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13738, dest: https://data.rkd.nl/artists/212582, score: 0.9922
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13739, dest: https://data.rkd.nl/artists/134841, score: 0.9910
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13750, dest: https://data.rkd.nl/artists/134841, score: 0.9910
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13760, dest: https://data.rkd.nl/artists/24689, score: 0.9976
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13762, dest: https://data.rkd.nl/artists/267462, score: 0.9920
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13777, dest: https://data.rkd.nl/artists/370297, score: 0.9880
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13779, dest: https://data.rkd.nl/artists/134841, score: 0.9938
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13780, dest: https://data.rkd.nl/artists/134841, score: 0.9905
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13785, dest: https://data.rkd.nl/artists/116471, score: 0.9900
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13787, dest: https://data.rkd.nl/artists/14418, score: 0.9971
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13793, dest: https://data.rkd.nl/artists/279595, score: 0.9937
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13794, dest: https://data.rkd.nl/artists/134841, score: 0.9919
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13795, dest: https://data.rkd.nl/artists/131165, score: 0.9942
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13838, dest: https://data.rkd.nl/artists/233340, score: 0.9938
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13933, dest: https://data.rkd.nl/artists/134841, score: 0.9894
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13936, dest: https://data.rkd.nl/artists/212582, score: 0.9935
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13938, dest: https://data.rkd.nl/artists/212582, score: 0.9944
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13947, dest: https://data.rkd.nl/artists/338058, score: 0.9959
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13952, dest: https://data.rkd.nl/artists/134841, score: 0.9859
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13965, dest: https://data.rkd.nl/artists/370297, score: 0.9945
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13969, dest: https://data.rkd.nl/artists/212582, score: 0.9932
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13982, dest: https://data.rkd.nl/artists/212582, score: 0.9949
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13985, dest: https://data.rkd.nl/artists/370297, score: 0.9928
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/13996, dest: https://data.rkd.nl/artists/279595, score: 0.9857
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/140346, dest: https://data.rkd.nl/artists/131165, score: 0.9981
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14065, dest: https://data.rkd.nl/artists/134841, score: 0.9843
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14089, dest: https://data.rkd.nl/artists/134841, score: 0.9923
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14102, dest: https://data.rkd.nl/artists/212582, score: 0.9951
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14117, dest: https://data.rkd.nl/artists/134841, score: 0.9867
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14139, dest: https://data.rkd.nl/artists/245667, score: 0.9823
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14149, dest: https://data.rkd.nl/artists/212582, score: 0.9932
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14150, dest: https://data.rkd.nl/artists/219622, score: 0.9972
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14153, dest: https://data.rkd.nl/artists/267462, score: 0.9845
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14156, dest: https://data.rkd.nl/artists/338058, score: 0.9938
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14157, dest: https://data.rkd.nl/artists/134841, score: 0.9902
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14159, dest: https://data.rkd.nl/artists/279595, score: 0.9967
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14161, dest: https://data.rkd.nl/artists/134841, score: 0.9860
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14164, dest: https://data.rkd.nl/artists/388601, score: 0.9862
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14166, dest: https://data.rkd.nl/artists/212582, score: 0.9879
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14167, dest: https://data.rkd.nl/artists/212582, score: 0.9873
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14191, dest: https://data.rkd.nl/artists/66525, score: 0.9945
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14197, dest: https://data.rkd.nl/artists/338058, score: 0.9969
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14230, dest: https://data.rkd.nl/artists/134841, score: 0.9818
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14232, dest: https://data.rkd.nl/artists/267462, score: 0.9892
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14239, dest: https://data.rkd.nl/artists/388601, score: 0.9902
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14253, dest: https://data.rkd.nl/artists/92568, score: 0.9993
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14305, dest: https://data.rkd.nl/artists/132409, score: 0.9803
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14430, dest: https://data.rkd.nl/artists/66525, score: 0.9970
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14431, dest: https://data.rkd.nl/artists/388601, score: 0.9851
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14433, dest: https://data.rkd.nl/artists/381502, score: 0.9927
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14470, dest: https://data.rkd.nl/artists/388601, score: 0.9859
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14516, dest: https://data.rkd.nl/artists/134841, score: 0.9858
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14655, dest: https://data.rkd.nl/artists/370297, score: 0.9903
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14668, dest: https://data.rkd.nl/artists/232076, score: 0.9941
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14685, dest: https://data.rkd.nl/artists/279595, score: 0.9902
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14694, dest: https://data.rkd.nl/artists/66525, score: 0.9929
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14754, dest: https://data.rkd.nl/artists/212582, score: 0.9949
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14777, dest: https://data.rkd.nl/artists/212582, score: 0.9944
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14788, dest: https://data.rkd.nl/artists/212582, score: 0.9917
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14795, dest: https://data.rkd.nl/artists/212582, score: 0.9871
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14839, dest: https://data.rkd.nl/artists/267462, score: 0.9899
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14856, dest: https://data.rkd.nl/artists/2684, score: 0.9966
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14890, dest: https://data.rkd.nl/artists/388601, score: 0.9845
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14892, dest: https://data.rkd.nl/artists/212582, score: 0.9979
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14905, dest: https://data.rkd.nl/artists/256476, score: 0.9890
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14906, dest: https://data.rkd.nl/artists/287865, score: 0.9845
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14976, dest: https://data.rkd.nl/artists/304342, score: 0.9864
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/14984, dest: https://data.rkd.nl/artists/338058, score: 0.9891
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15151, dest: https://data.rkd.nl/artists/212582, score: 0.9957
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15168, dest: https://data.rkd.nl/artists/212582, score: 0.9941
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15209, dest: https://data.rkd.nl/artists/134841, score: 0.9960
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/152181, dest: https://data.rkd.nl/artists/388601, score: 0.9887
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15257, dest: https://data.rkd.nl/artists/388601, score: 0.9837
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15269, dest: https://data.rkd.nl/artists/170512, score: 0.9979
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/152739, dest: https://data.rkd.nl/artists/388601, score: 0.9917
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/152867, dest: https://data.rkd.nl/artists/304342, score: 0.9812
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/152937, dest: https://data.rkd.nl/artists/212582, score: 0.9890
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/152993, dest: https://data.rkd.nl/artists/212582, score: 0.9927
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/153266, dest: https://data.rkd.nl/artists/212582, score: 0.9904
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15344, dest: https://data.rkd.nl/artists/370297, score: 0.9935
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15364, dest: https://data.rkd.nl/artists/388601, score: 0.9847
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/153700, dest: https://data.rkd.nl/artists/134841, score: 0.9947
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15496, dest: https://data.rkd.nl/artists/134841, score: 0.9900
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15620, dest: https://data.rkd.nl/artists/425362, score: 0.9947
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15643, dest: https://data.rkd.nl/artists/388601, score: 0.9872
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15660, dest: https://data.rkd.nl/artists/388601, score: 0.9862
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15669, dest: https://data.rkd.nl/artists/267462, score: 0.9913
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15681, dest: https://data.rkd.nl/artists/134841, score: 0.9847
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15818, dest: https://data.rkd.nl/artists/134841, score: 0.9897
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15845, dest: https://data.rkd.nl/artists/134841, score: 0.9937
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15856, dest: https://data.rkd.nl/artists/134841, score: 0.9862
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15866, dest: https://data.rkd.nl/artists/212582, score: 0.9923
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15877, dest: https://data.rkd.nl/artists/212582, score: 0.9924
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15917, dest: https://data.rkd.nl/artists/370297, score: 0.9901
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15925, dest: https://data.rkd.nl/artists/267462, score: 0.9851
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15956, dest: https://data.rkd.nl/artists/212582, score: 0.9963
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15968, dest: https://data.rkd.nl/artists/388601, score: 0.9891
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15989, dest: https://data.rkd.nl/artists/245667, score: 0.9806
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/15991, dest: https://data.rkd.nl/artists/212582, score: 0.9909
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/16029, dest: https://data.rkd.nl/artists/212582, score: 0.9916
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/16053, dest: https://data.rkd.nl/artists/212582, score: 0.9819
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/16105, dest: https://data.rkd.nl/artists/134841, score: 0.9902
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/16107, dest: https://data.rkd.nl/artists/232076, score: 0.9933
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/16117, dest: https://data.rkd.nl/artists/134841, score: 0.9887
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/16136, dest: https://data.rkd.nl/artists/388601, score: 0.9847
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/16211, dest: https://data.rkd.nl/artists/116471, score: 0.9900
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/16383, dest: https://data.rkd.nl/artists/212582, score: 0.9834
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/16522, dest: https://data.rkd.nl/artists/134841, score: 0.9859
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/16524, dest: https://data.rkd.nl/artists/134841, score: 0.9898
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/16748, dest: https://data.rkd.nl/artists/388601, score: 0.9912
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/16794, dest: https://data.rkd.nl/artists/212582, score: 0.9873
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/16795, dest: https://data.rkd.nl/artists/388601, score: 0.9893
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/16814, dest: https://data.rkd.nl/artists/304342, score: 0.9913
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/16905, dest: https://data.rkd.nl/artists/134841, score: 0.9933
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/16932, dest: https://data.rkd.nl/artists/229133, score: 0.9963
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/16961, dest: https://data.rkd.nl/artists/370297, score: 0.9955
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/17120, dest: https://data.rkd.nl/artists/370297, score: 0.9872
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/17121, dest: https://data.rkd.nl/artists/212582, score: 0.9867
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/17261, dest: https://data.rkd.nl/artists/212582, score: 0.9909
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/17283, dest: https://data.rkd.nl/artists/245667, score: 0.9902
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/17284, dest: https://data.rkd.nl/artists/245667, score: 0.9901
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/17295, dest: https://data.rkd.nl/artists/89910, score: 0.9808
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/17645, dest: https://data.rkd.nl/artists/134841, score: 0.9914
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/17787, dest: https://data.rkd.nl/artists/134841, score: 0.9847
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/17937, dest: https://data.rkd.nl/artists/212582, score: 0.9874
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/17939, dest: https://data.rkd.nl/artists/267462, score: 0.9901
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/18016, dest: https://data.rkd.nl/artists/134841, score: 0.9890
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/18153, dest: https://data.rkd.nl/artists/232076, score: 0.9983
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/18213, dest: https://data.rkd.nl/artists/388601, score: 0.9886
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/18719, dest: https://data.rkd.nl/artists/134841, score: 0.9936
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/18839, dest: https://data.rkd.nl/artists/212582, score: 0.9907
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/18966, dest: https://data.rkd.nl/artists/232076, score: 0.9946
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/18973, dest: https://data.rkd.nl/artists/338058, score: 0.9981
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/19153, dest: https://data.rkd.nl/artists/212582, score: 0.9907
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/19358, dest: https://data.rkd.nl/artists/232076, score: 0.9964
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/19740, dest: https://data.rkd.nl/artists/89910, score: 0.9885
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/19742, dest: https://data.rkd.nl/artists/134841, score: 0.9886
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/19759, dest: https://data.rkd.nl/artists/93178, score: 0.9921
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/19809, dest: https://data.rkd.nl/artists/74509, score: 0.9994
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/19883, dest: https://data.rkd.nl/artists/134841, score: 0.9897
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/19921, dest: https://data.rkd.nl/artists/212582, score: 0.9908
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/20201, dest: https://data.rkd.nl/artists/212582, score: 0.9870
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/20445, dest: https://data.rkd.nl/artists/232076, score: 0.9933
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/20913, dest: https://data.rkd.nl/artists/134841, score: 0.9920
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/21193, dest: https://data.rkd.nl/artists/388601, score: 0.9933
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/21379, dest: https://data.rkd.nl/artists/134841, score: 0.9906
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/21456, dest: https://data.rkd.nl/artists/267462, score: 0.9855
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/21502, dest: https://data.rkd.nl/artists/454488, score: 0.9974
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/21505, dest: https://data.rkd.nl/artists/338058, score: 0.9972
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/21552, dest: https://data.rkd.nl/artists/134841, score: 0.9946
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/21566, dest: https://data.rkd.nl/artists/388601, score: 0.9971
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/21754, dest: https://data.rkd.nl/artists/134841, score: 0.9907
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/21953, dest: https://data.rkd.nl/artists/388601, score: 0.9824
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/22008, dest: https://data.rkd.nl/artists/376113, score: 0.9939
# ...
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52362, dest: https://data.rkd.nl/artists/134841, score: 0.9911
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52390, dest: https://data.rkd.nl/artists/212582, score: 0.9959
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52404, dest: https://data.rkd.nl/artists/454488, score: 0.9961
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52435, dest: https://data.rkd.nl/artists/134841, score: 0.9940
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52437, dest: https://data.rkd.nl/artists/132409, score: 0.9947
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52462, dest: https://data.rkd.nl/artists/338058, score: 0.9946
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52477, dest: https://data.rkd.nl/artists/88401, score: 0.9843
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52479, dest: https://data.rkd.nl/artists/212582, score: 0.9919
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52545, dest: https://data.rkd.nl/artists/212582, score: 0.9900
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52557, dest: https://data.rkd.nl/artists/212582, score: 0.9923
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52561, dest: https://data.rkd.nl/artists/212582, score: 0.9924
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52567, dest: https://data.rkd.nl/artists/134841, score: 0.9906
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52577, dest: https://data.rkd.nl/artists/212582, score: 0.9941
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52615, dest: https://data.rkd.nl/artists/212582, score: 0.9918
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52633, dest: https://data.rkd.nl/artists/388601, score: 0.9865
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52656, dest: https://data.rkd.nl/artists/134841, score: 0.9934
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52703, dest: https://data.rkd.nl/artists/212582, score: 0.9895
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52737, dest: https://data.rkd.nl/artists/212582, score: 0.9872
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52741, dest: https://data.rkd.nl/artists/132409, score: 0.9922
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52759, dest: https://data.rkd.nl/artists/212582, score: 0.9912
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52763, dest: https://data.rkd.nl/artists/388601, score: 0.9892
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52841, dest: https://data.rkd.nl/artists/134841, score: 0.9915
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52842, dest: https://data.rkd.nl/artists/134841, score: 0.9911
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52847, dest: https://data.rkd.nl/artists/92206, score: 0.9940
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52870, dest: https://data.rkd.nl/artists/212582, score: 0.9974
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52895, dest: https://data.rkd.nl/artists/2684, score: 0.9977
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52896, dest: https://data.rkd.nl/artists/212582, score: 0.9958
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52919, dest: https://data.rkd.nl/artists/212582, score: 0.9939
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52921, dest: https://data.rkd.nl/artists/134841, score: 0.9939
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52930, dest: https://data.rkd.nl/artists/212582, score: 0.9905
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/52964, dest: https://data.rkd.nl/artists/370297, score: 0.9894
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53018, dest: https://data.rkd.nl/artists/245667, score: 0.9930
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53031, dest: https://data.rkd.nl/artists/212582, score: 0.9890
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53037, dest: https://data.rkd.nl/artists/134841, score: 0.9904
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53042, dest: https://data.rkd.nl/artists/370297, score: 0.9932
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53062, dest: https://data.rkd.nl/artists/132409, score: 0.9979
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53070, dest: https://data.rkd.nl/artists/134841, score: 0.9924
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53096, dest: https://data.rkd.nl/artists/66525, score: 0.9909
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53113, dest: https://data.rkd.nl/artists/388601, score: 0.9872
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53133, dest: https://data.rkd.nl/artists/338058, score: 0.9982
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53213, dest: https://data.rkd.nl/artists/212582, score: 0.9957
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53253, dest: https://data.rkd.nl/artists/212582, score: 0.9898
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53265, dest: https://data.rkd.nl/artists/66525, score: 0.9892
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53280, dest: https://data.rkd.nl/artists/133493, score: 0.9970
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53285, dest: https://data.rkd.nl/artists/338058, score: 0.9887
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53329, dest: https://data.rkd.nl/artists/212582, score: 0.9884
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53342, dest: https://data.rkd.nl/artists/212582, score: 0.9946
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53373, dest: https://data.rkd.nl/artists/132409, score: 0.9960
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/53442, dest: https://data.rkd.nl/artists/134841, score: 0.9871
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54127, dest: https://data.rkd.nl/artists/134841, score: 0.9874
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54170, dest: https://data.rkd.nl/artists/212582, score: 0.9920
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54269, dest: https://data.rkd.nl/artists/245667, score: 0.9818
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54275, dest: https://data.rkd.nl/artists/212582, score: 0.9956
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54305, dest: https://data.rkd.nl/artists/212582, score: 0.9985
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54326, dest: https://data.rkd.nl/artists/132409, score: 0.9923
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54451, dest: https://data.rkd.nl/artists/212582, score: 0.9898
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54489, dest: https://data.rkd.nl/artists/134841, score: 0.9928
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54547, dest: https://data.rkd.nl/artists/132409, score: 0.9927
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54604, dest: https://data.rkd.nl/artists/212582, score: 0.9869
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54632, dest: https://data.rkd.nl/artists/212582, score: 0.9871
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54633, dest: https://data.rkd.nl/artists/454488, score: 0.9916
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54755, dest: https://data.rkd.nl/artists/134841, score: 0.9936
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54760, dest: https://data.rkd.nl/artists/134841, score: 0.9905
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54801, dest: https://data.rkd.nl/artists/212582, score: 0.9916
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54849, dest: https://data.rkd.nl/artists/212582, score: 0.9943
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54853, dest: https://data.rkd.nl/artists/134841, score: 0.9904
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54867, dest: https://data.rkd.nl/artists/212582, score: 0.9895
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54881, dest: https://data.rkd.nl/artists/338058, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54915, dest: https://data.rkd.nl/artists/212582, score: 0.9955
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/54985, dest: https://data.rkd.nl/artists/29851, score: 0.9997
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/55001, dest: https://data.rkd.nl/artists/425362, score: 0.9963
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/55064, dest: https://data.rkd.nl/artists/132409, score: 0.9952
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/55282, dest: https://data.rkd.nl/artists/232076, score: 0.9972
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/55326, dest: https://data.rkd.nl/artists/232076, score: 0.9957
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/55366, dest: https://data.rkd.nl/artists/134841, score: 0.9907
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/56484, dest: https://data.rkd.nl/artists/212582, score: 0.9916
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/57008, dest: https://data.rkd.nl/artists/388601, score: 0.9801
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/58168, dest: https://data.rkd.nl/artists/132409, score: 0.9973
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/58171, dest: https://data.rkd.nl/artists/132409, score: 0.9974
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/58322, dest: https://data.rkd.nl/artists/233340, score: 0.9904
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/58793, dest: https://data.rkd.nl/artists/212582, score: 0.9924
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/59266, dest: https://data.rkd.nl/artists/134841, score: 0.9955
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/59268, dest: https://data.rkd.nl/artists/212582, score: 0.9926
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/59406, dest: https://data.rkd.nl/artists/265206, score: 0.9981
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/59930, dest: https://data.rkd.nl/artists/338058, score: 0.9899
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/60584, dest: https://data.rkd.nl/artists/212582, score: 0.9874
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/60681, dest: https://data.rkd.nl/artists/212582, score: 0.9896
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/61542, dest: https://data.rkd.nl/artists/304342, score: 0.9872
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/62222, dest: https://data.rkd.nl/artists/425362, score: 0.9962
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/62349, dest: https://data.rkd.nl/artists/287865, score: 0.9846
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/62751, dest: https://data.rkd.nl/artists/132409, score: 0.9944
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/63089, dest: https://data.rkd.nl/artists/212582, score: 0.9884
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/63144, dest: https://data.rkd.nl/artists/212582, score: 0.9971
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/63350, dest: https://data.rkd.nl/artists/132409, score: 0.9921
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/63797, dest: https://data.rkd.nl/artists/131165, score: 0.9952
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/64352, dest: https://data.rkd.nl/artists/304342, score: 0.9874
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/65587, dest: https://data.rkd.nl/artists/212582, score: 0.9930
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/66140, dest: https://data.rkd.nl/artists/212582, score: 0.9975
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/66359, dest: https://data.rkd.nl/artists/338058, score: 0.9919
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/67112, dest: https://data.rkd.nl/artists/25626, score: 0.9987
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/67115, dest: https://data.rkd.nl/artists/212582, score: 0.9877
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/67862, dest: https://data.rkd.nl/artists/134841, score: 0.9944
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/68688, dest: https://data.rkd.nl/artists/370297, score: 0.9894
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/68855, dest: https://data.rkd.nl/artists/277905, score: 0.9990
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/68865, dest: https://data.rkd.nl/artists/134841, score: 0.9847
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/69338, dest: https://data.rkd.nl/artists/212582, score: 0.9960
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/69406, dest: https://data.rkd.nl/artists/212582, score: 0.9944
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/69682, dest: https://data.rkd.nl/artists/297671, score: 0.9920
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/70024, dest: https://data.rkd.nl/artists/231562, score: 0.9989
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/70083, dest: https://data.rkd.nl/artists/212582, score: 0.9931
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/70395, dest: https://data.rkd.nl/artists/233340, score: 0.9979
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/71072, dest: https://data.rkd.nl/artists/338058, score: 0.9945
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/71282, dest: https://data.rkd.nl/artists/81190, score: 0.9928
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/71665, dest: https://data.rkd.nl/artists/212582, score: 0.9958
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/71951, dest: https://data.rkd.nl/artists/304342, score: 0.9884
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/71997, dest: https://data.rkd.nl/artists/304342, score: 0.9946
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/72575, dest: https://data.rkd.nl/artists/287865, score: 0.9877
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/74291, dest: https://data.rkd.nl/artists/388601, score: 0.9804
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/74779, dest: https://data.rkd.nl/artists/388601, score: 0.9930
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/75846, dest: https://data.rkd.nl/artists/212582, score: 0.9916
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/76178, dest: https://data.rkd.nl/artists/388601, score: 0.9933
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/76250, dest: https://data.rkd.nl/artists/212582, score: 0.9910
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/77269, dest: https://data.rkd.nl/artists/126926, score: 0.9970
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/78323, dest: https://data.rkd.nl/artists/132409, score: 0.9866
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/80473, dest: https://data.rkd.nl/artists/134841, score: 0.9903
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/84732, dest: https://data.rkd.nl/artists/388601, score: 0.9891
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/88217, dest: https://data.rkd.nl/artists/212582, score: 0.9915
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/90089, dest: https://data.rkd.nl/artists/212582, score: 0.9935
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/90841, dest: https://data.rkd.nl/artists/212582, score: 0.9972
# src: https://collectiedata.hetnieuweinstituut.nl/id/people/93867, dest: https://data.rkd.nl/artists/370297, score: 0.9852
# Highest Similarity Score: 0.9999338984489441

# %%
validation_path = join(config.validation_sheets_path, 'NIxRKD.csv')

# %%
creat_validation_sheet(validation_path, similar_rkd_pairs_dict, ni_etl_obj.triples, rkd_etl_obj.triples)
# Out:
# saved to /home/muhammad/Downloads/LOD-Linker/results/validation/NIxRKD.csv ...

# %% [markdown]
# ## Show Case

# %%
triples_factory.entities_to_ids(["Zurich"])
# Out:
# [34479]

# %%
test_src_vec = embeddings_entity_np[13260,:].reshape(1, -1)

# %%
test_src_vec.shape
# Out:
# (1, 6)

# %%
triples_factory.entities_to_ids(["The Hague"])
# Out:
# [32234]

# %%
test_dest_vec = embeddings_entity_np[20543,:].reshape(1, -1)

# %%
test_dest_vec.shape
# Out:
# (1, 6)

# %%
cosine_similarity(test_src_vec, test_dest_vec)
# Out:
# array([[0.11625753]], dtype=float32)

# %%
triples_factory.entities_to_ids(["Rotterdam", "Amsterdam"])
# Out:
# [30386, 15364]

# %%
test_src_vec = embeddings_entity_np[19468,:].reshape(1, -1)

# %%
test_dest_vec = embeddings_entity_np[11364,:].reshape(1, -1)

# %%
cosine_similarity(test_src_vec, test_dest_vec)
# Out:
# array([[-0.11711449]], dtype=float32)

# %% [markdown]
# ## References

# %% [markdown]
# https://analyticsindiamag.com/ai-mysteries/complete-guide-to-pykeen-python-knowledge-embeddings-for-knowledge-graphs/#h-results
#
#
# https://github.com/pykeen/pykeen/blob/master/docs/source/tutorial/first_steps.rst#using-learned-embeddings
#
#
# https://wasit7.medium.com/tutorial-knowledge-graph-embedding-with-pykeen-22d3b7847cea
